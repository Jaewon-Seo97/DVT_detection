# %%
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import tensorflow as tf
import keras 
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from keras import backend as K
from keras.utils import plot_model
from keras.models import load_model
from keras.utils import multi_gpu_model
import cv2
from tqdm import tqdm, tqdm_notebook
from sklearn.model_selection import train_test_split
from keras.layers import *
from keras.models import Model
from keras import backend as K
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
import random
import pandas as pd
from keras import losses
from skimage.io import imsave, imread
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
pwd
# Out:
# '/home/ubuntu/gcubme4/Workspace/JW_Seo/p_project/code'

# %%
def base_block(inputs, base = 4, scale = 2):
    
#     x = Conv2D(base, 3, strides= 1, activation=None, padding='same', kernel_initializer='he_normal')(inputs)
#     x = BatchNormalization()(x)
#     x = Activation(activation='relu')(x)
    
    x = Conv2D(base, 3, strides=1, activation=None, padding='same', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    base_out = Activation(activation='relu')(x)

    
    return base_out
def base_classification_jw(inputs, base=16, scale = 2):
    
    layer=3
    for br in range(layer):
        
        if br == 0:
            print(br)
            conv= base_block(inputs)
            
            conv = MaxPooling2D(pool_size=(3, 3), strides = 2)(conv)
            print(conv.shape)
            
        else:
            print(br)
            print(conv.shape, scale, br, base)
            num = (scale**br) *  base
            conv= base_block(conv, base= num)
            print(conv.shape)
            print(num)
    
            conv= MaxPooling2D(pool_size=(2, 2), strides = 2)(conv)
            print(conv.shape)
    for ar in range(layer):
        print(num)
        num = int(num/scale)
        conv = base_block(conv, base = num)
        print(num)    
        
            
    out= Flatten()(conv)
  
#     out = Dense(64, activation="relu")(out)
    out = Dense(1, activation="sigmoid")(out)
    
    
    
    model = Model(inputs=inputs, outputs=out)
    
    return model

# %%
from keras.models import Sequential

input_img = Input(shape=(32,32,1))
model = base_classification_jw(input_img, base = 4, scale = 2)
model.summary()
# Out:
# 0
# (None, 15, 15, 4)
# 1
# (None, 15, 15, 4) 2 1 4
# (None, 15, 15, 8)
# 8
# (None, 7, 7, 8)
# 2
# (None, 7, 7, 8) 2 2 4
# (None, 7, 7, 16)
# 16
# (None, 3, 3, 16)
# 16
# 8
# 8
# 4
# 4
# 2
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 4)         40
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 4)         16
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 4)         0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 4)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 8)         296
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 8)         32
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 8)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 16)          1168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 16)          64
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 16)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 16)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 8)           1160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 3, 8)           32
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 3, 8)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 4)           292
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 3, 4)           16
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 3, 4)           0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 2)           74
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 3, 3, 2)           8
# _________________________________________________________________
# activation_6 (Activation)    (None, 3, 3, 2)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 19
# =================================================================
# Total params: 3,217
# Trainable params: 3,133
# Non-trainable params: 84
# _________________________________________________________________

# %%
print("loading data")

img_train = np.load('../train_img_32_bilinear.npy')
img_test = np.load('../test_img_32_bilinear.npy')
lab_train= np.load('../train_label_32_bilinear.npy')
lab_test= np. load('../test_label_32_bilinear.npy')


print("loading data done")
print(img_train.shape)
print(img_test.shape)
print(lab_train.shape)
print(lab_test.shape)
# Out:
# loading data
# loading data done
# (70, 32, 32, 1)
# (32, 32, 32, 1)
# (70,)
# (32,)

# %%
help(model.compile)
# Out:
# Help on method compile in module keras.engine.training:
#
# compile(optimizer, loss=None, metrics=None, loss_weights=None, sample_weight_mode=None, weighted_metrics=None, target_tensors=None, **kwargs) method of keras.engine.training.Model instance
#     Configures the model for training.
#
#     # Arguments
#         optimizer: String (name of optimizer) or optimizer instance.
#             See [optimizers](/optimizers).
#         loss: String (name of objective function) or objective function or
#             `Loss` instance. See [losses](/losses).
#             If the model has multiple outputs, you can use a different loss
#             on each output by passing a dictionary or a list of losses.
#             The loss value that will be minimized by the model
#             will then be the sum of all individual losses.
#         metrics: List of metrics to be evaluated by the model
#             during training and testing. Typically you will use
#             `metrics=['accuracy']`. To specify different metrics for different
#             outputs of a multi-output model, you could also pass a dictionary,
#             such as
#             `metrics={'output_a': 'accuracy', 'output_b': ['accuracy', 'mse']}`.
#             You can also pass a list (len = len(outputs)) of lists of metrics
#             such as `metrics=[['accuracy'], ['accuracy', 'mse']]` or
#             `metrics=['accuracy', ['accuracy', 'mse']]`.
#         loss_weights: Optional list or dictionary specifying scalar
#             coefficients (Python floats) to weight the loss contributions
#             of different model outputs.
#             The loss value that will be minimized by the model
#             will then be the *weighted sum* of all individual losses,
#             weighted by the `loss_weights` coefficients.
#             If a list, it is expected to have a 1:1 mapping
#             to the model's outputs. If a dict, it is expected to map
#             output names (strings) to scalar coefficients.
#         sample_weight_mode: If you need to do timestep-wise
#             sample weighting (2D weights), set this to `"temporal"`.
#             `None` defaults to sample-wise weights (1D).
#             If the model has multiple outputs, you can use a different
#             `sample_weight_mode` on each output by passing a
#             dictionary or a list of modes.
#         weighted_metrics: List of metrics to be evaluated and weighted
#             by sample_weight or class_weight during training and testing.
#         target_tensors: By default, Keras will create placeholders for the
#             model's target, which will be fed with the target data during
#             training. If instead you would like to use your own
#             target tensors (in turn, Keras will not expect external
#             Numpy data for these targets at training time), you
#             can specify them via the `target_tensors` argument. It can be
#             a single tensor (for a single-output model), a list of tensors,
#             or a dict mapping output names to target tensors.
#         **kwargs: When using the Theano/CNTK backends, these arguments
#             are passed into `K.function`.
#             When using the TensorFlow backend,
#             these arguments are passed into `tf.Session.run`.
#
#     # Raises
#         ValueError: In case of invalid arguments for
#             `optimizer`, `loss`, `metrics` or `sample_weight_mode`.

# %%
pwd
# Out:
# '/home/ubuntu/gcubme4/Workspace/JW_Seo/DVT_detection/blood_vessel/code'

# %%
model.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath='basic_class_32_bilinear.h5', verbose=1, save_best_only=True, monitor='loss')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.1,
                              patience=10, min_lr=0, min_delta=0.001, verbose=1)
earlystopper = EarlyStopping(patience=30, verbose=1, monitor='loss')
callbacks_list = [reduce_lr, checkpointer, earlystopper]

# %%
# results = model.fit(img_train, loc_train, batch_size=4, epochs=500, verbose=1, validation_split=0.1, shuffle=True, callbacks=callbacks_list)
results = model.fit(img_train, lab_train, batch_size=128, epochs=500, verbose=1, shuffle=False,  callbacks=callbacks_list)
# Out:
# Epoch 1/500
# 70/70 [==============================] - 2s 24ms/step - loss: 0.6323 - accuracy: 0.5571
#
# Epoch 00001: loss improved from inf to 0.63229, saving model to basic_class_32_bilinear.h5
# Epoch 2/500
# 70/70 [==============================] - 0s 174us/step - loss: 0.5774 - accuracy: 0.6286
#
# Epoch 00002: loss improved from 0.63229 to 0.57745, saving model to basic_class_32_bilinear.h5
# Epoch 3/500
# 70/70 [==============================] - 0s 226us/step - loss: 0.5346 - accuracy: 0.6571
#
# Epoch 00003: loss improved from 0.57745 to 0.53463, saving model to basic_class_32_bilinear.h5
# Epoch 4/500
# 70/70 [==============================] - 0s 211us/step - loss: 0.5007 - accuracy: 0.7429
#
# Epoch 00004: loss improved from 0.53463 to 0.50065, saving model to basic_class_32_bilinear.h5
# Epoch 5/500
# 70/70 [==============================] - 0s 202us/step - loss: 0.4722 - accuracy: 0.8286
#
# Epoch 00005: loss improved from 0.50065 to 0.47216, saving model to basic_class_32_bilinear.h5
# Epoch 6/500
# 70/70 [==============================] - 0s 233us/step - loss: 0.4489 - accuracy: 0.8429
#
# Epoch 00006: loss improved from 0.47216 to 0.44892, saving model to basic_class_32_bilinear.h5
# Epoch 7/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.4286 - accuracy: 0.8571
#
# Epoch 00007: loss improved from 0.44892 to 0.42860, saving model to basic_class_32_bilinear.h5
# Epoch 8/500
# 70/70 [==============================] - 0s 189us/step - loss: 0.4103 - accuracy: 0.8857
#
# Epoch 00008: loss improved from 0.42860 to 0.41032, saving model to basic_class_32_bilinear.h5
# Epoch 9/500
# 70/70 [==============================] - 0s 159us/step - loss: 0.3930 - accuracy: 0.9286
#
# Epoch 00009: loss improved from 0.41032 to 0.39302, saving model to basic_class_32_bilinear.h5
# Epoch 10/500
# 70/70 [==============================] - 0s 257us/step - loss: 0.3753 - accuracy: 0.9286
#
# Epoch 00010: loss improved from 0.39302 to 0.37533, saving model to basic_class_32_bilinear.h5
# Epoch 11/500
# 70/70 [==============================] - 0s 133us/step - loss: 0.3586 - accuracy: 0.9571
#
# Epoch 00011: loss improved from 0.37533 to 0.35860, saving model to basic_class_32_bilinear.h5
# Epoch 12/500
# 70/70 [==============================] - 0s 149us/step - loss: 0.3431 - accuracy: 0.9571
#
# Epoch 00012: loss improved from 0.35860 to 0.34315, saving model to basic_class_32_bilinear.h5
# Epoch 13/500
# 70/70 [==============================] - 0s 215us/step - loss: 0.3290 - accuracy: 0.9571
#
# Epoch 00013: loss improved from 0.34315 to 0.32901, saving model to basic_class_32_bilinear.h5
# Epoch 14/500
# 70/70 [==============================] - 0s 186us/step - loss: 0.3166 - accuracy: 0.9571
#
# Epoch 00014: loss improved from 0.32901 to 0.31662, saving model to basic_class_32_bilinear.h5
# Epoch 15/500
# 70/70 [==============================] - 0s 155us/step - loss: 0.3049 - accuracy: 0.9571
#
# Epoch 00015: loss improved from 0.31662 to 0.30490, saving model to basic_class_32_bilinear.h5
# Epoch 16/500
# 70/70 [==============================] - 0s 124us/step - loss: 0.2944 - accuracy: 0.9714
#
# Epoch 00016: loss improved from 0.30490 to 0.29436, saving model to basic_class_32_bilinear.h5
# Epoch 17/500
# 70/70 [==============================] - 0s 183us/step - loss: 0.2849 - accuracy: 0.9714
#
# Epoch 00017: loss improved from 0.29436 to 0.28488, saving model to basic_class_32_bilinear.h5
# Epoch 18/500
# 70/70 [==============================] - 0s 191us/step - loss: 0.2760 - accuracy: 0.9714
#
# Epoch 00018: loss improved from 0.28488 to 0.27600, saving model to basic_class_32_bilinear.h5
# Epoch 19/500
# 70/70 [==============================] - 0s 231us/step - loss: 0.2673 - accuracy: 1.0000
#
# Epoch 00019: loss improved from 0.27600 to 0.26729, saving model to basic_class_32_bilinear.h5
# Epoch 20/500
# 70/70 [==============================] - 0s 240us/step - loss: 0.2589 - accuracy: 1.0000
#
# Epoch 00020: loss improved from 0.26729 to 0.25890, saving model to basic_class_32_bilinear.h5
# Epoch 21/500
# 70/70 [==============================] - 0s 212us/step - loss: 0.2508 - accuracy: 1.0000
#
# Epoch 00021: loss improved from 0.25890 to 0.25077, saving model to basic_class_32_bilinear.h5
# Epoch 22/500
# 70/70 [==============================] - 0s 173us/step - loss: 0.2429 - accuracy: 1.0000
#
# Epoch 00022: loss improved from 0.25077 to 0.24286, saving model to basic_class_32_bilinear.h5
# Epoch 23/500
# 70/70 [==============================] - 0s 195us/step - loss: 0.2351 - accuracy: 1.0000
#
# Epoch 00023: loss improved from 0.24286 to 0.23509, saving model to basic_class_32_bilinear.h5
# Epoch 24/500
# 70/70 [==============================] - 0s 172us/step - loss: 0.2277 - accuracy: 1.0000
#
# Epoch 00024: loss improved from 0.23509 to 0.22767, saving model to basic_class_32_bilinear.h5
# Epoch 25/500
# 70/70 [==============================] - 0s 171us/step - loss: 0.2207 - accuracy: 1.0000
#
# Epoch 00025: loss improved from 0.22767 to 0.22072, saving model to basic_class_32_bilinear.h5
# Epoch 26/500
# 70/70 [==============================] - 0s 176us/step - loss: 0.2141 - accuracy: 1.0000
#
# Epoch 00026: loss improved from 0.22072 to 0.21414, saving model to basic_class_32_bilinear.h5
# Epoch 27/500
# 70/70 [==============================] - 0s 189us/step - loss: 0.2079 - accuracy: 1.0000
#
# Epoch 00027: loss improved from 0.21414 to 0.20785, saving model to basic_class_32_bilinear.h5
# Epoch 28/500
# 70/70 [==============================] - 0s 216us/step - loss: 0.2018 - accuracy: 1.0000
#
# Epoch 00028: loss improved from 0.20785 to 0.20182, saving model to basic_class_32_bilinear.h5
# Epoch 29/500
# 70/70 [==============================] - 0s 191us/step - loss: 0.1959 - accuracy: 1.0000
#
# Epoch 00029: loss improved from 0.20182 to 0.19593, saving model to basic_class_32_bilinear.h5
# Epoch 30/500
# 70/70 [==============================] - 0s 205us/step - loss: 0.1902 - accuracy: 1.0000
#
# Epoch 00030: loss improved from 0.19593 to 0.19020, saving model to basic_class_32_bilinear.h5
# Epoch 31/500
# 70/70 [==============================] - 0s 178us/step - loss: 0.1847 - accuracy: 1.0000
#
# Epoch 00031: loss improved from 0.19020 to 0.18465, saving model to basic_class_32_bilinear.h5
# Epoch 32/500
# 70/70 [==============================] - 0s 227us/step - loss: 0.1792 - accuracy: 1.0000
#
# Epoch 00032: loss improved from 0.18465 to 0.17919, saving model to basic_class_32_bilinear.h5
# Epoch 33/500
# 70/70 [==============================] - 0s 196us/step - loss: 0.1739 - accuracy: 1.0000
#
# Epoch 00033: loss improved from 0.17919 to 0.17394, saving model to basic_class_32_bilinear.h5
# Epoch 34/500
# 70/70 [==============================] - 0s 197us/step - loss: 0.1690 - accuracy: 1.0000
#
# Epoch 00034: loss improved from 0.17394 to 0.16896, saving model to basic_class_32_bilinear.h5
# Epoch 35/500
# 70/70 [==============================] - 0s 162us/step - loss: 0.1641 - accuracy: 1.0000
#
# Epoch 00035: loss improved from 0.16896 to 0.16412, saving model to basic_class_32_bilinear.h5
# Epoch 36/500
# 70/70 [==============================] - 0s 223us/step - loss: 0.1595 - accuracy: 1.0000
#
# Epoch 00036: loss improved from 0.16412 to 0.15951, saving model to basic_class_32_bilinear.h5
# Epoch 37/500
# 70/70 [==============================] - 0s 192us/step - loss: 0.1552 - accuracy: 1.0000
#
# Epoch 00037: loss improved from 0.15951 to 0.15517, saving model to basic_class_32_bilinear.h5
# Epoch 38/500
# 70/70 [==============================] - 0s 181us/step - loss: 0.1509 - accuracy: 1.0000
#
# Epoch 00038: loss improved from 0.15517 to 0.15094, saving model to basic_class_32_bilinear.h5
# Epoch 39/500
# 70/70 [==============================] - 0s 161us/step - loss: 0.1468 - accuracy: 1.0000
#
# Epoch 00039: loss improved from 0.15094 to 0.14684, saving model to basic_class_32_bilinear.h5
# Epoch 40/500
# 70/70 [==============================] - 0s 237us/step - loss: 0.1429 - accuracy: 1.0000
#
# Epoch 00040: loss improved from 0.14684 to 0.14287, saving model to basic_class_32_bilinear.h5
# Epoch 41/500
# 70/70 [==============================] - 0s 194us/step - loss: 0.1391 - accuracy: 1.0000
#
# Epoch 00041: loss improved from 0.14287 to 0.13909, saving model to basic_class_32_bilinear.h5
# Epoch 42/500
# 70/70 [==============================] - 0s 193us/step - loss: 0.1355 - accuracy: 1.0000
#
# Epoch 00042: loss improved from 0.13909 to 0.13546, saving model to basic_class_32_bilinear.h5
# Epoch 43/500
# 70/70 [==============================] - 0s 258us/step - loss: 0.1320 - accuracy: 1.0000
#
# Epoch 00043: loss improved from 0.13546 to 0.13202, saving model to basic_class_32_bilinear.h5
# Epoch 44/500
# 70/70 [==============================] - 0s 227us/step - loss: 0.1287 - accuracy: 1.0000
#
# Epoch 00044: loss improved from 0.13202 to 0.12871, saving model to basic_class_32_bilinear.h5
# Epoch 45/500
# 70/70 [==============================] - 0s 204us/step - loss: 0.1256 - accuracy: 1.0000
#
# Epoch 00045: loss improved from 0.12871 to 0.12559, saving model to basic_class_32_bilinear.h5
# Epoch 46/500
# 70/70 [==============================] - 0s 143us/step - loss: 0.1226 - accuracy: 1.0000
#
# Epoch 00046: loss improved from 0.12559 to 0.12261, saving model to basic_class_32_bilinear.h5
# Epoch 47/500
# 70/70 [==============================] - 0s 210us/step - loss: 0.1198 - accuracy: 1.0000
#
# Epoch 00047: loss improved from 0.12261 to 0.11977, saving model to basic_class_32_bilinear.h5
# Epoch 48/500
# 70/70 [==============================] - 0s 214us/step - loss: 0.1171 - accuracy: 1.0000
#
# Epoch 00048: loss improved from 0.11977 to 0.11710, saving model to basic_class_32_bilinear.h5
# Epoch 49/500
# 70/70 [==============================] - 0s 222us/step - loss: 0.1146 - accuracy: 1.0000
#
# Epoch 00049: loss improved from 0.11710 to 0.11458, saving model to basic_class_32_bilinear.h5
# Epoch 50/500
# 70/70 [==============================] - 0s 177us/step - loss: 0.1121 - accuracy: 1.0000
#
# Epoch 00050: loss improved from 0.11458 to 0.11214, saving model to basic_class_32_bilinear.h5
# Epoch 51/500
# 70/70 [==============================] - 0s 201us/step - loss: 0.1098 - accuracy: 1.0000
#
# Epoch 00051: loss improved from 0.11214 to 0.10978, saving model to basic_class_32_bilinear.h5
# Epoch 52/500
# 70/70 [==============================] - 0s 251us/step - loss: 0.1075 - accuracy: 1.0000
#
# Epoch 00052: loss improved from 0.10978 to 0.10753, saving model to basic_class_32_bilinear.h5
# Epoch 53/500
# 70/70 [==============================] - 0s 178us/step - loss: 0.1053 - accuracy: 1.0000
#
# Epoch 00053: loss improved from 0.10753 to 0.10534, saving model to basic_class_32_bilinear.h5
# Epoch 54/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.1032 - accuracy: 1.0000
#
# Epoch 00054: loss improved from 0.10534 to 0.10323, saving model to basic_class_32_bilinear.h5
# Epoch 55/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.1012 - accuracy: 1.0000
#
# Epoch 00055: loss improved from 0.10323 to 0.10120, saving model to basic_class_32_bilinear.h5
# Epoch 56/500
# 70/70 [==============================] - 0s 168us/step - loss: 0.0992 - accuracy: 1.0000
#
# Epoch 00056: loss improved from 0.10120 to 0.09924, saving model to basic_class_32_bilinear.h5
# Epoch 57/500
# 70/70 [==============================] - 0s 185us/step - loss: 0.0973 - accuracy: 1.0000
#
# Epoch 00057: loss improved from 0.09924 to 0.09732, saving model to basic_class_32_bilinear.h5
# Epoch 58/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0954 - accuracy: 1.0000
#
# Epoch 00058: loss improved from 0.09732 to 0.09544, saving model to basic_class_32_bilinear.h5
# Epoch 59/500
# 70/70 [==============================] - 0s 221us/step - loss: 0.0936 - accuracy: 1.0000
#
# Epoch 00059: loss improved from 0.09544 to 0.09359, saving model to basic_class_32_bilinear.h5
# Epoch 60/500
# 70/70 [==============================] - 0s 249us/step - loss: 0.0918 - accuracy: 1.0000
#
# Epoch 00060: loss improved from 0.09359 to 0.09180, saving model to basic_class_32_bilinear.h5
# Epoch 61/500
# 70/70 [==============================] - 0s 243us/step - loss: 0.0901 - accuracy: 1.0000
#
# Epoch 00061: loss improved from 0.09180 to 0.09012, saving model to basic_class_32_bilinear.h5
# Epoch 62/500
# 70/70 [==============================] - 0s 154us/step - loss: 0.0885 - accuracy: 1.0000
#
# Epoch 00062: loss improved from 0.09012 to 0.08850, saving model to basic_class_32_bilinear.h5
# Epoch 63/500
# 70/70 [==============================] - 0s 188us/step - loss: 0.0870 - accuracy: 1.0000
#
# Epoch 00063: loss improved from 0.08850 to 0.08696, saving model to basic_class_32_bilinear.h5
# Epoch 64/500
# 70/70 [==============================] - 0s 228us/step - loss: 0.0855 - accuracy: 1.0000
#
# Epoch 00064: loss improved from 0.08696 to 0.08547, saving model to basic_class_32_bilinear.h5
# Epoch 65/500
# 70/70 [==============================] - 0s 160us/step - loss: 0.0841 - accuracy: 1.0000
#
# Epoch 00065: loss improved from 0.08547 to 0.08406, saving model to basic_class_32_bilinear.h5
# Epoch 66/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.0827 - accuracy: 1.0000
#
# Epoch 00066: loss improved from 0.08406 to 0.08269, saving model to basic_class_32_bilinear.h5
# Epoch 67/500
# 70/70 [==============================] - 0s 212us/step - loss: 0.0813 - accuracy: 1.0000
#
# Epoch 00067: loss improved from 0.08269 to 0.08134, saving model to basic_class_32_bilinear.h5
# Epoch 68/500
# 70/70 [==============================] - 0s 223us/step - loss: 0.0800 - accuracy: 1.0000
#
# Epoch 00068: loss improved from 0.08134 to 0.08002, saving model to basic_class_32_bilinear.h5
# Epoch 69/500
# 70/70 [==============================] - 0s 164us/step - loss: 0.0787 - accuracy: 1.0000
#
# Epoch 00069: loss improved from 0.08002 to 0.07875, saving model to basic_class_32_bilinear.h5
# Epoch 70/500
# 70/70 [==============================] - 0s 245us/step - loss: 0.0775 - accuracy: 1.0000
#
# Epoch 00070: loss improved from 0.07875 to 0.07751, saving model to basic_class_32_bilinear.h5
# Epoch 71/500
# 70/70 [==============================] - 0s 204us/step - loss: 0.0763 - accuracy: 1.0000
#
# Epoch 00071: loss improved from 0.07751 to 0.07630, saving model to basic_class_32_bilinear.h5
# Epoch 72/500
# 70/70 [==============================] - 0s 177us/step - loss: 0.0751 - accuracy: 1.0000
#
# Epoch 00072: loss improved from 0.07630 to 0.07513, saving model to basic_class_32_bilinear.h5
# Epoch 73/500
# 70/70 [==============================] - 0s 190us/step - loss: 0.0740 - accuracy: 1.0000
#
# Epoch 00073: loss improved from 0.07513 to 0.07397, saving model to basic_class_32_bilinear.h5
# Epoch 74/500
# 70/70 [==============================] - 0s 227us/step - loss: 0.0729 - accuracy: 1.0000
#
# Epoch 00074: loss improved from 0.07397 to 0.07285, saving model to basic_class_32_bilinear.h5
# Epoch 75/500
# 70/70 [==============================] - 0s 199us/step - loss: 0.0718 - accuracy: 1.0000
#
# Epoch 00075: loss improved from 0.07285 to 0.07177, saving model to basic_class_32_bilinear.h5
# Epoch 76/500
# 70/70 [==============================] - 0s 172us/step - loss: 0.0707 - accuracy: 1.0000
#
# Epoch 00076: loss improved from 0.07177 to 0.07071, saving model to basic_class_32_bilinear.h5
# Epoch 77/500
# 70/70 [==============================] - 0s 182us/step - loss: 0.0697 - accuracy: 1.0000
#
# Epoch 00077: loss improved from 0.07071 to 0.06969, saving model to basic_class_32_bilinear.h5
# Epoch 78/500
# 70/70 [==============================] - 0s 165us/step - loss: 0.0687 - accuracy: 1.0000
#
# Epoch 00078: loss improved from 0.06969 to 0.06870, saving model to basic_class_32_bilinear.h5
# Epoch 79/500
# 70/70 [==============================] - 0s 235us/step - loss: 0.0677 - accuracy: 1.0000
#
# Epoch 00079: loss improved from 0.06870 to 0.06773, saving model to basic_class_32_bilinear.h5
# Epoch 80/500
# 70/70 [==============================] - 0s 174us/step - loss: 0.0668 - accuracy: 1.0000
#
# Epoch 00080: loss improved from 0.06773 to 0.06680, saving model to basic_class_32_bilinear.h5
# Epoch 81/500
# 70/70 [==============================] - 0s 169us/step - loss: 0.0659 - accuracy: 1.0000
#
# Epoch 00081: loss improved from 0.06680 to 0.06589, saving model to basic_class_32_bilinear.h5
# Epoch 82/500
# 70/70 [==============================] - 0s 212us/step - loss: 0.0650 - accuracy: 1.0000
#
# Epoch 00082: loss improved from 0.06589 to 0.06500, saving model to basic_class_32_bilinear.h5
# Epoch 83/500
# 70/70 [==============================] - 0s 187us/step - loss: 0.0641 - accuracy: 1.0000
#
# Epoch 00083: loss improved from 0.06500 to 0.06412, saving model to basic_class_32_bilinear.h5
# Epoch 84/500
# 70/70 [==============================] - 0s 192us/step - loss: 0.0633 - accuracy: 1.0000
#
# Epoch 00084: loss improved from 0.06412 to 0.06327, saving model to basic_class_32_bilinear.h5
# Epoch 85/500
# 70/70 [==============================] - 0s 215us/step - loss: 0.0624 - accuracy: 1.0000
#
# Epoch 00085: loss improved from 0.06327 to 0.06244, saving model to basic_class_32_bilinear.h5
# Epoch 86/500
# 70/70 [==============================] - 0s 183us/step - loss: 0.0616 - accuracy: 1.0000
#
# Epoch 00086: loss improved from 0.06244 to 0.06162, saving model to basic_class_32_bilinear.h5
# Epoch 87/500
# 70/70 [==============================] - 0s 226us/step - loss: 0.0608 - accuracy: 1.0000
#
# Epoch 00087: loss improved from 0.06162 to 0.06082, saving model to basic_class_32_bilinear.h5
# Epoch 88/500
# 70/70 [==============================] - 0s 194us/step - loss: 0.0600 - accuracy: 1.0000
#
# Epoch 00088: loss improved from 0.06082 to 0.06004, saving model to basic_class_32_bilinear.h5
# Epoch 89/500
# 70/70 [==============================] - 0s 176us/step - loss: 0.0593 - accuracy: 1.0000
#
# Epoch 00089: loss improved from 0.06004 to 0.05927, saving model to basic_class_32_bilinear.h5
# Epoch 90/500
# 70/70 [==============================] - 0s 211us/step - loss: 0.0585 - accuracy: 1.0000
#
# Epoch 00090: loss improved from 0.05927 to 0.05853, saving model to basic_class_32_bilinear.h5
# Epoch 91/500
# 70/70 [==============================] - 0s 175us/step - loss: 0.0578 - accuracy: 1.0000
#
# Epoch 00091: loss improved from 0.05853 to 0.05781, saving model to basic_class_32_bilinear.h5
# Epoch 92/500
# 70/70 [==============================] - 0s 209us/step - loss: 0.0571 - accuracy: 1.0000
#
# Epoch 00092: loss improved from 0.05781 to 0.05710, saving model to basic_class_32_bilinear.h5
# Epoch 93/500
# 70/70 [==============================] - 0s 204us/step - loss: 0.0564 - accuracy: 1.0000
#
# Epoch 00093: loss improved from 0.05710 to 0.05641, saving model to basic_class_32_bilinear.h5
# Epoch 94/500
# 70/70 [==============================] - 0s 202us/step - loss: 0.0557 - accuracy: 1.0000
#
# Epoch 00094: loss improved from 0.05641 to 0.05573, saving model to basic_class_32_bilinear.h5
# Epoch 95/500
# 70/70 [==============================] - 0s 212us/step - loss: 0.0551 - accuracy: 1.0000
#
# Epoch 00095: loss improved from 0.05573 to 0.05506, saving model to basic_class_32_bilinear.h5
# Epoch 96/500
# 70/70 [==============================] - 0s 182us/step - loss: 0.0544 - accuracy: 1.0000
#
# Epoch 00096: loss improved from 0.05506 to 0.05441, saving model to basic_class_32_bilinear.h5
# Epoch 97/500
# 70/70 [==============================] - 0s 200us/step - loss: 0.0538 - accuracy: 1.0000
#
# Epoch 00097: loss improved from 0.05441 to 0.05376, saving model to basic_class_32_bilinear.h5
# Epoch 98/500
# 70/70 [==============================] - 0s 243us/step - loss: 0.0531 - accuracy: 1.0000
#
# Epoch 00098: loss improved from 0.05376 to 0.05313, saving model to basic_class_32_bilinear.h5
# Epoch 99/500
# 70/70 [==============================] - 0s 223us/step - loss: 0.0525 - accuracy: 1.0000
#
# Epoch 00099: loss improved from 0.05313 to 0.05251, saving model to basic_class_32_bilinear.h5
# Epoch 100/500
# 70/70 [==============================] - 0s 156us/step - loss: 0.0519 - accuracy: 1.0000
#
# Epoch 00100: loss improved from 0.05251 to 0.05190, saving model to basic_class_32_bilinear.h5
# Epoch 101/500
# 70/70 [==============================] - 0s 219us/step - loss: 0.0513 - accuracy: 1.0000
#
# Epoch 00101: loss improved from 0.05190 to 0.05131, saving model to basic_class_32_bilinear.h5
# Epoch 102/500
# 70/70 [==============================] - 0s 214us/step - loss: 0.0507 - accuracy: 1.0000
#
# Epoch 00102: loss improved from 0.05131 to 0.05072, saving model to basic_class_32_bilinear.h5
# Epoch 103/500
# 70/70 [==============================] - 0s 191us/step - loss: 0.0502 - accuracy: 1.0000
#
# Epoch 00103: loss improved from 0.05072 to 0.05015, saving model to basic_class_32_bilinear.h5
# Epoch 104/500
# 70/70 [==============================] - 0s 160us/step - loss: 0.0496 - accuracy: 1.0000
#
# Epoch 00104: loss improved from 0.05015 to 0.04959, saving model to basic_class_32_bilinear.h5
# Epoch 105/500
# 70/70 [==============================] - 0s 181us/step - loss: 0.0490 - accuracy: 1.0000
#
# Epoch 00105: loss improved from 0.04959 to 0.04904, saving model to basic_class_32_bilinear.h5
# Epoch 106/500
# 70/70 [==============================] - 0s 232us/step - loss: 0.0485 - accuracy: 1.0000
#
# Epoch 00106: loss improved from 0.04904 to 0.04850, saving model to basic_class_32_bilinear.h5
# Epoch 107/500
# 70/70 [==============================] - 0s 222us/step - loss: 0.0480 - accuracy: 1.0000
#
# Epoch 00107: loss improved from 0.04850 to 0.04796, saving model to basic_class_32_bilinear.h5
# Epoch 108/500
# 70/70 [==============================] - 0s 183us/step - loss: 0.0474 - accuracy: 1.0000
#
# Epoch 00108: loss improved from 0.04796 to 0.04743, saving model to basic_class_32_bilinear.h5
# Epoch 109/500
# 70/70 [==============================] - 0s 231us/step - loss: 0.0469 - accuracy: 1.0000
#
# Epoch 00109: loss improved from 0.04743 to 0.04692, saving model to basic_class_32_bilinear.h5
# Epoch 110/500
# 70/70 [==============================] - 0s 205us/step - loss: 0.0464 - accuracy: 1.0000
#
# Epoch 00110: loss improved from 0.04692 to 0.04641, saving model to basic_class_32_bilinear.h5
# Epoch 111/500
# 70/70 [==============================] - 0s 154us/step - loss: 0.0459 - accuracy: 1.0000
#
# Epoch 00111: loss improved from 0.04641 to 0.04592, saving model to basic_class_32_bilinear.h5
# Epoch 112/500
# 70/70 [==============================] - 0s 236us/step - loss: 0.0454 - accuracy: 1.0000
#
# Epoch 00112: loss improved from 0.04592 to 0.04543, saving model to basic_class_32_bilinear.h5
# Epoch 113/500
# 70/70 [==============================] - 0s 180us/step - loss: 0.0449 - accuracy: 1.0000
#
# Epoch 00113: loss improved from 0.04543 to 0.04495, saving model to basic_class_32_bilinear.h5
# Epoch 114/500
# 70/70 [==============================] - 0s 158us/step - loss: 0.0445 - accuracy: 1.0000
#
# Epoch 00114: loss improved from 0.04495 to 0.04448, saving model to basic_class_32_bilinear.h5
# Epoch 115/500
# 70/70 [==============================] - 0s 181us/step - loss: 0.0440 - accuracy: 1.0000
#
# Epoch 00115: loss improved from 0.04448 to 0.04402, saving model to basic_class_32_bilinear.h5
# Epoch 116/500
# 70/70 [==============================] - 0s 159us/step - loss: 0.0436 - accuracy: 1.0000
#
# Epoch 00116: loss improved from 0.04402 to 0.04356, saving model to basic_class_32_bilinear.h5
# Epoch 117/500
# 70/70 [==============================] - 0s 170us/step - loss: 0.0431 - accuracy: 1.0000
#
# Epoch 00117: loss improved from 0.04356 to 0.04311, saving model to basic_class_32_bilinear.h5
# Epoch 118/500
# 70/70 [==============================] - 0s 212us/step - loss: 0.0427 - accuracy: 1.0000
#
# Epoch 00118: loss improved from 0.04311 to 0.04266, saving model to basic_class_32_bilinear.h5
# Epoch 119/500
# 70/70 [==============================] - 0s 204us/step - loss: 0.0422 - accuracy: 1.0000
#
# Epoch 00119: loss improved from 0.04266 to 0.04223, saving model to basic_class_32_bilinear.h5
# Epoch 120/500
# 70/70 [==============================] - 0s 173us/step - loss: 0.0418 - accuracy: 1.0000
#
# Epoch 00120: loss improved from 0.04223 to 0.04179, saving model to basic_class_32_bilinear.h5
# Epoch 121/500
# 70/70 [==============================] - 0s 209us/step - loss: 0.0414 - accuracy: 1.0000
#
# Epoch 00121: loss improved from 0.04179 to 0.04137, saving model to basic_class_32_bilinear.h5
# Epoch 122/500
# 70/70 [==============================] - 0s 186us/step - loss: 0.0410 - accuracy: 1.0000
#
# Epoch 00122: loss improved from 0.04137 to 0.04095, saving model to basic_class_32_bilinear.h5
# Epoch 123/500
# 70/70 [==============================] - 0s 161us/step - loss: 0.0405 - accuracy: 1.0000
#
# Epoch 00123: loss improved from 0.04095 to 0.04054, saving model to basic_class_32_bilinear.h5
# Epoch 124/500
# 70/70 [==============================] - 0s 200us/step - loss: 0.0401 - accuracy: 1.0000
#
# Epoch 00124: loss improved from 0.04054 to 0.04013, saving model to basic_class_32_bilinear.h5
# Epoch 125/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.0397 - accuracy: 1.0000
#
# Epoch 00125: loss improved from 0.04013 to 0.03973, saving model to basic_class_32_bilinear.h5
# Epoch 126/500
# 70/70 [==============================] - 0s 181us/step - loss: 0.0393 - accuracy: 1.0000
#
# Epoch 00126: loss improved from 0.03973 to 0.03934, saving model to basic_class_32_bilinear.h5
# Epoch 127/500
# 70/70 [==============================] - 0s 157us/step - loss: 0.0389 - accuracy: 1.0000
#
# Epoch 00127: loss improved from 0.03934 to 0.03895, saving model to basic_class_32_bilinear.h5
# Epoch 128/500
# 70/70 [==============================] - 0s 179us/step - loss: 0.0386 - accuracy: 1.0000
#
# Epoch 00128: loss improved from 0.03895 to 0.03856, saving model to basic_class_32_bilinear.h5
# Epoch 129/500
# 70/70 [==============================] - 0s 173us/step - loss: 0.0382 - accuracy: 1.0000
#
# Epoch 00129: loss improved from 0.03856 to 0.03819, saving model to basic_class_32_bilinear.h5
# Epoch 130/500
# 70/70 [==============================] - 0s 228us/step - loss: 0.0378 - accuracy: 1.0000
#
# Epoch 00130: loss improved from 0.03819 to 0.03781, saving model to basic_class_32_bilinear.h5
# Epoch 131/500
# 70/70 [==============================] - 0s 227us/step - loss: 0.0374 - accuracy: 1.0000
#
# Epoch 00131: loss improved from 0.03781 to 0.03745, saving model to basic_class_32_bilinear.h5
# Epoch 132/500
# 70/70 [==============================] - 0s 180us/step - loss: 0.0371 - accuracy: 1.0000
#
# Epoch 00132: loss improved from 0.03745 to 0.03708, saving model to basic_class_32_bilinear.h5
# Epoch 133/500
# 70/70 [==============================] - 0s 222us/step - loss: 0.0367 - accuracy: 1.0000
#
# Epoch 00133: loss improved from 0.03708 to 0.03673, saving model to basic_class_32_bilinear.h5
# Epoch 134/500
# 70/70 [==============================] - 0s 140us/step - loss: 0.0364 - accuracy: 1.0000
#
# Epoch 00134: loss improved from 0.03673 to 0.03637, saving model to basic_class_32_bilinear.h5
# Epoch 135/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.0360 - accuracy: 1.0000
#
# Epoch 00135: loss improved from 0.03637 to 0.03603, saving model to basic_class_32_bilinear.h5
# Epoch 136/500
# 70/70 [==============================] - 0s 192us/step - loss: 0.0357 - accuracy: 1.0000
#
# Epoch 00136: loss improved from 0.03603 to 0.03568, saving model to basic_class_32_bilinear.h5
# Epoch 137/500
# 70/70 [==============================] - 0s 193us/step - loss: 0.0353 - accuracy: 1.0000
#
# Epoch 00137: loss improved from 0.03568 to 0.03534, saving model to basic_class_32_bilinear.h5
# Epoch 138/500
# 70/70 [==============================] - 0s 232us/step - loss: 0.0350 - accuracy: 1.0000
#
# Epoch 00138: loss improved from 0.03534 to 0.03501, saving model to basic_class_32_bilinear.h5
# Epoch 139/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0347 - accuracy: 1.0000
#
# Epoch 00139: loss improved from 0.03501 to 0.03468, saving model to basic_class_32_bilinear.h5
# Epoch 140/500
# 70/70 [==============================] - 0s 148us/step - loss: 0.0344 - accuracy: 1.0000
#
# Epoch 00140: loss improved from 0.03468 to 0.03435, saving model to basic_class_32_bilinear.h5
# Epoch 141/500
# 70/70 [==============================] - 0s 165us/step - loss: 0.0340 - accuracy: 1.0000
#
# Epoch 00141: loss improved from 0.03435 to 0.03403, saving model to basic_class_32_bilinear.h5
# Epoch 142/500
# 70/70 [==============================] - 0s 190us/step - loss: 0.0337 - accuracy: 1.0000
#
# Epoch 00142: loss improved from 0.03403 to 0.03372, saving model to basic_class_32_bilinear.h5
# Epoch 143/500
# 70/70 [==============================] - 0s 182us/step - loss: 0.0334 - accuracy: 1.0000
#
# Epoch 00143: loss improved from 0.03372 to 0.03340, saving model to basic_class_32_bilinear.h5
# Epoch 144/500
# 70/70 [==============================] - 0s 183us/step - loss: 0.0331 - accuracy: 1.0000
#
# Epoch 00144: loss improved from 0.03340 to 0.03310, saving model to basic_class_32_bilinear.h5
# Epoch 145/500
# 70/70 [==============================] - 0s 226us/step - loss: 0.0328 - accuracy: 1.0000
#
# Epoch 00145: loss improved from 0.03310 to 0.03279, saving model to basic_class_32_bilinear.h5
# Epoch 146/500
# 70/70 [==============================] - 0s 218us/step - loss: 0.0325 - accuracy: 1.0000
#
# Epoch 00146: loss improved from 0.03279 to 0.03249, saving model to basic_class_32_bilinear.h5
# Epoch 147/500
# 70/70 [==============================] - 0s 183us/step - loss: 0.0322 - accuracy: 1.0000
#
# Epoch 00147: loss improved from 0.03249 to 0.03220, saving model to basic_class_32_bilinear.h5
# Epoch 148/500
# 70/70 [==============================] - 0s 208us/step - loss: 0.0319 - accuracy: 1.0000
#
# Epoch 00148: loss improved from 0.03220 to 0.03190, saving model to basic_class_32_bilinear.h5
# Epoch 149/500
# 70/70 [==============================] - 0s 241us/step - loss: 0.0316 - accuracy: 1.0000
#
# Epoch 00149: loss improved from 0.03190 to 0.03162, saving model to basic_class_32_bilinear.h5
# Epoch 150/500
# 70/70 [==============================] - 0s 208us/step - loss: 0.0313 - accuracy: 1.0000
#
# Epoch 00150: loss improved from 0.03162 to 0.03133, saving model to basic_class_32_bilinear.h5
# Epoch 151/500
# 70/70 [==============================] - 0s 170us/step - loss: 0.0311 - accuracy: 1.0000
#
# Epoch 00151: loss improved from 0.03133 to 0.03105, saving model to basic_class_32_bilinear.h5
# Epoch 152/500
# 70/70 [==============================] - 0s 221us/step - loss: 0.0308 - accuracy: 1.0000
#
# Epoch 00152: loss improved from 0.03105 to 0.03077, saving model to basic_class_32_bilinear.h5
# Epoch 153/500
# 70/70 [==============================] - 0s 172us/step - loss: 0.0305 - accuracy: 1.0000
#
# Epoch 00153: loss improved from 0.03077 to 0.03050, saving model to basic_class_32_bilinear.h5
# Epoch 154/500
# 70/70 [==============================] - 0s 226us/step - loss: 0.0302 - accuracy: 1.0000
#
# Epoch 00154: loss improved from 0.03050 to 0.03023, saving model to basic_class_32_bilinear.h5
# Epoch 155/500
# 70/70 [==============================] - 0s 211us/step - loss: 0.0300 - accuracy: 1.0000
#
# Epoch 00155: loss improved from 0.03023 to 0.02996, saving model to basic_class_32_bilinear.h5
# Epoch 156/500
# 70/70 [==============================] - 0s 211us/step - loss: 0.0297 - accuracy: 1.0000
#
# Epoch 00156: loss improved from 0.02996 to 0.02970, saving model to basic_class_32_bilinear.h5
# Epoch 157/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0294 - accuracy: 1.0000
#
# Epoch 00157: loss improved from 0.02970 to 0.02944, saving model to basic_class_32_bilinear.h5
# Epoch 158/500
# 70/70 [==============================] - 0s 212us/step - loss: 0.0292 - accuracy: 1.0000
#
# Epoch 00158: loss improved from 0.02944 to 0.02918, saving model to basic_class_32_bilinear.h5
# Epoch 159/500
# 70/70 [==============================] - 0s 246us/step - loss: 0.0289 - accuracy: 1.0000
#
# Epoch 00159: loss improved from 0.02918 to 0.02893, saving model to basic_class_32_bilinear.h5
# Epoch 160/500
# 70/70 [==============================] - 0s 227us/step - loss: 0.0287 - accuracy: 1.0000
#
# Epoch 00160: loss improved from 0.02893 to 0.02868, saving model to basic_class_32_bilinear.h5
# Epoch 161/500
# 70/70 [==============================] - 0s 202us/step - loss: 0.0284 - accuracy: 1.0000
#
# Epoch 00161: loss improved from 0.02868 to 0.02843, saving model to basic_class_32_bilinear.h5
# Epoch 162/500
# 70/70 [==============================] - 0s 193us/step - loss: 0.0282 - accuracy: 1.0000
#
# Epoch 00162: loss improved from 0.02843 to 0.02819, saving model to basic_class_32_bilinear.h5
# Epoch 163/500
# 70/70 [==============================] - 0s 222us/step - loss: 0.0279 - accuracy: 1.0000
#
# Epoch 00163: loss improved from 0.02819 to 0.02795, saving model to basic_class_32_bilinear.h5
# Epoch 164/500
# 70/70 [==============================] - 0s 217us/step - loss: 0.0277 - accuracy: 1.0000
#
# Epoch 00164: loss improved from 0.02795 to 0.02771, saving model to basic_class_32_bilinear.h5
# Epoch 165/500
# 70/70 [==============================] - 0s 205us/step - loss: 0.0275 - accuracy: 1.0000
#
# Epoch 00165: loss improved from 0.02771 to 0.02747, saving model to basic_class_32_bilinear.h5
# Epoch 166/500
# 70/70 [==============================] - 0s 178us/step - loss: 0.0272 - accuracy: 1.0000
#
# Epoch 00166: loss improved from 0.02747 to 0.02724, saving model to basic_class_32_bilinear.h5
# Epoch 167/500
# 70/70 [==============================] - 0s 159us/step - loss: 0.0270 - accuracy: 1.0000
#
# Epoch 00167: loss improved from 0.02724 to 0.02701, saving model to basic_class_32_bilinear.h5
# Epoch 168/500
# 70/70 [==============================] - 0s 207us/step - loss: 0.0268 - accuracy: 1.0000
#
# Epoch 00168: loss improved from 0.02701 to 0.02678, saving model to basic_class_32_bilinear.h5
# Epoch 169/500
# 70/70 [==============================] - 0s 180us/step - loss: 0.0266 - accuracy: 1.0000
#
# Epoch 00169: loss improved from 0.02678 to 0.02656, saving model to basic_class_32_bilinear.h5
# Epoch 170/500
# 70/70 [==============================] - 0s 158us/step - loss: 0.0263 - accuracy: 1.0000
#
# Epoch 00170: loss improved from 0.02656 to 0.02634, saving model to basic_class_32_bilinear.h5
# Epoch 171/500
# 70/70 [==============================] - 0s 209us/step - loss: 0.0261 - accuracy: 1.0000
#
# Epoch 00171: loss improved from 0.02634 to 0.02612, saving model to basic_class_32_bilinear.h5
# Epoch 172/500
# 70/70 [==============================] - 0s 194us/step - loss: 0.0259 - accuracy: 1.0000
#
# Epoch 00172: loss improved from 0.02612 to 0.02590, saving model to basic_class_32_bilinear.h5
# Epoch 173/500
# 70/70 [==============================] - 0s 144us/step - loss: 0.0257 - accuracy: 1.0000
#
# Epoch 00173: loss improved from 0.02590 to 0.02569, saving model to basic_class_32_bilinear.h5
# Epoch 174/500
# 70/70 [==============================] - 0s 145us/step - loss: 0.0255 - accuracy: 1.0000
#
# Epoch 00174: loss improved from 0.02569 to 0.02548, saving model to basic_class_32_bilinear.h5
# Epoch 175/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0253 - accuracy: 1.0000
#
# Epoch 00175: loss improved from 0.02548 to 0.02527, saving model to basic_class_32_bilinear.h5
# Epoch 176/500
# 70/70 [==============================] - 0s 217us/step - loss: 0.0251 - accuracy: 1.0000
#
# Epoch 00176: loss improved from 0.02527 to 0.02506, saving model to basic_class_32_bilinear.h5
# Epoch 177/500
# 70/70 [==============================] - 0s 253us/step - loss: 0.0249 - accuracy: 1.0000
#
# Epoch 00177: loss improved from 0.02506 to 0.02486, saving model to basic_class_32_bilinear.h5
# Epoch 178/500
# 70/70 [==============================] - 0s 157us/step - loss: 0.0247 - accuracy: 1.0000
#
# Epoch 00178: loss improved from 0.02486 to 0.02465, saving model to basic_class_32_bilinear.h5
# Epoch 179/500
# 70/70 [==============================] - 0s 222us/step - loss: 0.0245 - accuracy: 1.0000
#
# Epoch 00179: loss improved from 0.02465 to 0.02445, saving model to basic_class_32_bilinear.h5
# Epoch 180/500
# 70/70 [==============================] - 0s 199us/step - loss: 0.0243 - accuracy: 1.0000
#
# Epoch 00180: loss improved from 0.02445 to 0.02426, saving model to basic_class_32_bilinear.h5
# Epoch 181/500
# 70/70 [==============================] - 0s 215us/step - loss: 0.0241 - accuracy: 1.0000
#
# Epoch 00181: loss improved from 0.02426 to 0.02406, saving model to basic_class_32_bilinear.h5
# Epoch 182/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0239 - accuracy: 1.0000
#
# Epoch 00182: loss improved from 0.02406 to 0.02387, saving model to basic_class_32_bilinear.h5
# Epoch 183/500
# 70/70 [==============================] - 0s 203us/step - loss: 0.0237 - accuracy: 1.0000
#
# Epoch 00183: loss improved from 0.02387 to 0.02368, saving model to basic_class_32_bilinear.h5
# Epoch 184/500
# 70/70 [==============================] - 0s 135us/step - loss: 0.0235 - accuracy: 1.0000
#
# Epoch 00184: loss improved from 0.02368 to 0.02349, saving model to basic_class_32_bilinear.h5
# Epoch 185/500
# 70/70 [==============================] - 0s 135us/step - loss: 0.0233 - accuracy: 1.0000
#
# Epoch 00185: loss improved from 0.02349 to 0.02330, saving model to basic_class_32_bilinear.h5
# Epoch 186/500
# 70/70 [==============================] - 0s 202us/step - loss: 0.0231 - accuracy: 1.0000
#
# Epoch 00186: loss improved from 0.02330 to 0.02311, saving model to basic_class_32_bilinear.h5
# Epoch 187/500
# 70/70 [==============================] - 0s 149us/step - loss: 0.0229 - accuracy: 1.0000
#
# Epoch 00187: loss improved from 0.02311 to 0.02293, saving model to basic_class_32_bilinear.h5
# Epoch 188/500
# 70/70 [==============================] - 0s 171us/step - loss: 0.0228 - accuracy: 1.0000
#
# Epoch 00188: loss improved from 0.02293 to 0.02275, saving model to basic_class_32_bilinear.h5
# Epoch 189/500
# 70/70 [==============================] - 0s 168us/step - loss: 0.0226 - accuracy: 1.0000
#
# Epoch 00189: loss improved from 0.02275 to 0.02257, saving model to basic_class_32_bilinear.h5
# Epoch 190/500
# 70/70 [==============================] - 0s 213us/step - loss: 0.0224 - accuracy: 1.0000
#
# Epoch 00190: loss improved from 0.02257 to 0.02240, saving model to basic_class_32_bilinear.h5
# Epoch 191/500
# 70/70 [==============================] - 0s 188us/step - loss: 0.0222 - accuracy: 1.0000
#
# Epoch 00191: loss improved from 0.02240 to 0.02222, saving model to basic_class_32_bilinear.h5
# Epoch 192/500
# 70/70 [==============================] - 0s 191us/step - loss: 0.0220 - accuracy: 1.0000
#
# Epoch 00192: loss improved from 0.02222 to 0.02205, saving model to basic_class_32_bilinear.h5
# Epoch 193/500
# 70/70 [==============================] - 0s 197us/step - loss: 0.0219 - accuracy: 1.0000
#
# Epoch 00193: loss improved from 0.02205 to 0.02188, saving model to basic_class_32_bilinear.h5
# Epoch 194/500
# 70/70 [==============================] - 0s 192us/step - loss: 0.0217 - accuracy: 1.0000
#
# Epoch 00194: loss improved from 0.02188 to 0.02171, saving model to basic_class_32_bilinear.h5
# Epoch 195/500
# 70/70 [==============================] - 0s 189us/step - loss: 0.0215 - accuracy: 1.0000
#
# Epoch 00195: loss improved from 0.02171 to 0.02154, saving model to basic_class_32_bilinear.h5
# Epoch 196/500
# 70/70 [==============================] - 0s 246us/step - loss: 0.0214 - accuracy: 1.0000
#
# Epoch 00196: loss improved from 0.02154 to 0.02138, saving model to basic_class_32_bilinear.h5
# Epoch 197/500
# 70/70 [==============================] - 0s 207us/step - loss: 0.0212 - accuracy: 1.0000
#
# Epoch 00197: loss improved from 0.02138 to 0.02121, saving model to basic_class_32_bilinear.h5
# Epoch 198/500
# 70/70 [==============================] - 0s 173us/step - loss: 0.0211 - accuracy: 1.0000
#
# Epoch 00198: loss improved from 0.02121 to 0.02105, saving model to basic_class_32_bilinear.h5
# Epoch 199/500
# 70/70 [==============================] - 0s 192us/step - loss: 0.0209 - accuracy: 1.0000
#
# Epoch 00199: loss improved from 0.02105 to 0.02089, saving model to basic_class_32_bilinear.h5
# Epoch 200/500
# 70/70 [==============================] - 0s 173us/step - loss: 0.0207 - accuracy: 1.0000
#
# Epoch 00200: loss improved from 0.02089 to 0.02073, saving model to basic_class_32_bilinear.h5
# Epoch 201/500
# 70/70 [==============================] - 0s 225us/step - loss: 0.0206 - accuracy: 1.0000
#
# Epoch 00201: loss improved from 0.02073 to 0.02058, saving model to basic_class_32_bilinear.h5
# Epoch 202/500
# 70/70 [==============================] - 0s 238us/step - loss: 0.0204 - accuracy: 1.0000
#
# Epoch 00202: loss improved from 0.02058 to 0.02042, saving model to basic_class_32_bilinear.h5
# Epoch 203/500
# 70/70 [==============================] - 0s 148us/step - loss: 0.0203 - accuracy: 1.0000
#
# Epoch 00203: loss improved from 0.02042 to 0.02027, saving model to basic_class_32_bilinear.h5
# Epoch 204/500
# 70/70 [==============================] - 0s 181us/step - loss: 0.0201 - accuracy: 1.0000
#
# Epoch 00204: loss improved from 0.02027 to 0.02012, saving model to basic_class_32_bilinear.h5
# Epoch 205/500
# 70/70 [==============================] - 0s 188us/step - loss: 0.0200 - accuracy: 1.0000
#
# Epoch 00205: loss improved from 0.02012 to 0.01997, saving model to basic_class_32_bilinear.h5
# Epoch 206/500
# 70/70 [==============================] - 0s 188us/step - loss: 0.0198 - accuracy: 1.0000
#
# Epoch 00206: loss improved from 0.01997 to 0.01982, saving model to basic_class_32_bilinear.h5
# Epoch 207/500
# 70/70 [==============================] - 0s 223us/step - loss: 0.0197 - accuracy: 1.0000
#
# Epoch 00207: loss improved from 0.01982 to 0.01968, saving model to basic_class_32_bilinear.h5
# Epoch 208/500
# 70/70 [==============================] - 0s 213us/step - loss: 0.0195 - accuracy: 1.0000
#
# Epoch 00208: loss improved from 0.01968 to 0.01953, saving model to basic_class_32_bilinear.h5
# Epoch 209/500
# 70/70 [==============================] - 0s 252us/step - loss: 0.0194 - accuracy: 1.0000
#
# Epoch 00209: loss improved from 0.01953 to 0.01939, saving model to basic_class_32_bilinear.h5
# Epoch 210/500
# 70/70 [==============================] - 0s 224us/step - loss: 0.0192 - accuracy: 1.0000
#
# Epoch 00210: loss improved from 0.01939 to 0.01925, saving model to basic_class_32_bilinear.h5
# Epoch 211/500
# 70/70 [==============================] - 0s 261us/step - loss: 0.0191 - accuracy: 1.0000
#
# Epoch 00211: loss improved from 0.01925 to 0.01910, saving model to basic_class_32_bilinear.h5
# Epoch 212/500
# 70/70 [==============================] - 0s 205us/step - loss: 0.0190 - accuracy: 1.0000
#
# Epoch 00212: loss improved from 0.01910 to 0.01897, saving model to basic_class_32_bilinear.h5
# Epoch 213/500
# 70/70 [==============================] - 0s 161us/step - loss: 0.0188 - accuracy: 1.0000
#
# Epoch 00213: loss improved from 0.01897 to 0.01883, saving model to basic_class_32_bilinear.h5
# Epoch 214/500
# 70/70 [==============================] - 0s 200us/step - loss: 0.0187 - accuracy: 1.0000
#
# Epoch 00214: loss improved from 0.01883 to 0.01869, saving model to basic_class_32_bilinear.h5
# Epoch 215/500
# 70/70 [==============================] - 0s 173us/step - loss: 0.0186 - accuracy: 1.0000
#
# Epoch 00215: loss improved from 0.01869 to 0.01856, saving model to basic_class_32_bilinear.h5
# Epoch 216/500
# 70/70 [==============================] - 0s 171us/step - loss: 0.0184 - accuracy: 1.0000
#
# Epoch 00216: loss improved from 0.01856 to 0.01842, saving model to basic_class_32_bilinear.h5
# Epoch 217/500
# 70/70 [==============================] - 0s 218us/step - loss: 0.0183 - accuracy: 1.0000
#
# Epoch 00217: loss improved from 0.01842 to 0.01829, saving model to basic_class_32_bilinear.h5
# Epoch 218/500
# 70/70 [==============================] - 0s 246us/step - loss: 0.0182 - accuracy: 1.0000
#
# Epoch 00218: loss improved from 0.01829 to 0.01816, saving model to basic_class_32_bilinear.h5
# Epoch 219/500
# 70/70 [==============================] - 0s 186us/step - loss: 0.0180 - accuracy: 1.0000
#
# Epoch 00219: loss improved from 0.01816 to 0.01803, saving model to basic_class_32_bilinear.h5
# Epoch 220/500
# 70/70 [==============================] - 0s 184us/step - loss: 0.0179 - accuracy: 1.0000
#
# Epoch 00220: loss improved from 0.01803 to 0.01791, saving model to basic_class_32_bilinear.h5
# Epoch 221/500
# 70/70 [==============================] - 0s 200us/step - loss: 0.0178 - accuracy: 1.0000
#
# Epoch 00221: loss improved from 0.01791 to 0.01778, saving model to basic_class_32_bilinear.h5
# Epoch 222/500
# 70/70 [==============================] - 0s 212us/step - loss: 0.0177 - accuracy: 1.0000
#
# Epoch 00222: loss improved from 0.01778 to 0.01766, saving model to basic_class_32_bilinear.h5
# Epoch 223/500
# 70/70 [==============================] - 0s 148us/step - loss: 0.0175 - accuracy: 1.0000
#
# Epoch 00223: loss improved from 0.01766 to 0.01753, saving model to basic_class_32_bilinear.h5
# Epoch 224/500
# 70/70 [==============================] - 0s 211us/step - loss: 0.0174 - accuracy: 1.0000
#
# Epoch 00224: loss improved from 0.01753 to 0.01741, saving model to basic_class_32_bilinear.h5
# Epoch 225/500
# 70/70 [==============================] - 0s 221us/step - loss: 0.0173 - accuracy: 1.0000
#
# Epoch 00225: loss improved from 0.01741 to 0.01729, saving model to basic_class_32_bilinear.h5
# Epoch 226/500
# 70/70 [==============================] - 0s 214us/step - loss: 0.0172 - accuracy: 1.0000
#
# Epoch 00226: loss improved from 0.01729 to 0.01717, saving model to basic_class_32_bilinear.h5
# Epoch 227/500
# 70/70 [==============================] - 0s 235us/step - loss: 0.0171 - accuracy: 1.0000
#
# Epoch 00227: loss improved from 0.01717 to 0.01705, saving model to basic_class_32_bilinear.h5
# Epoch 228/500
# 70/70 [==============================] - 0s 229us/step - loss: 0.0169 - accuracy: 1.0000
#
# Epoch 00228: loss improved from 0.01705 to 0.01694, saving model to basic_class_32_bilinear.h5
# Epoch 229/500
# 70/70 [==============================] - 0s 211us/step - loss: 0.0168 - accuracy: 1.0000
#
# Epoch 00229: loss improved from 0.01694 to 0.01682, saving model to basic_class_32_bilinear.h5
# Epoch 230/500
# 70/70 [==============================] - 0s 207us/step - loss: 0.0167 - accuracy: 1.0000
#
# Epoch 00230: loss improved from 0.01682 to 0.01671, saving model to basic_class_32_bilinear.h5
# Epoch 231/500
# 70/70 [==============================] - 0s 199us/step - loss: 0.0166 - accuracy: 1.0000
#
# Epoch 00231: loss improved from 0.01671 to 0.01659, saving model to basic_class_32_bilinear.h5
# Epoch 232/500
# 70/70 [==============================] - 0s 213us/step - loss: 0.0165 - accuracy: 1.0000
#
# Epoch 00232: loss improved from 0.01659 to 0.01648, saving model to basic_class_32_bilinear.h5
# Epoch 233/500
# 70/70 [==============================] - 0s 180us/step - loss: 0.0164 - accuracy: 1.0000
#
# Epoch 00233: loss improved from 0.01648 to 0.01637, saving model to basic_class_32_bilinear.h5
# Epoch 234/500
# 70/70 [==============================] - 0s 219us/step - loss: 0.0163 - accuracy: 1.0000
#
# Epoch 00234: loss improved from 0.01637 to 0.01626, saving model to basic_class_32_bilinear.h5
# Epoch 235/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.0162 - accuracy: 1.0000
#
# Epoch 00235: loss improved from 0.01626 to 0.01615, saving model to basic_class_32_bilinear.h5
# Epoch 236/500
# 70/70 [==============================] - 0s 232us/step - loss: 0.0160 - accuracy: 1.0000
#
# Epoch 00236: loss improved from 0.01615 to 0.01604, saving model to basic_class_32_bilinear.h5
# Epoch 237/500
# 70/70 [==============================] - 0s 173us/step - loss: 0.0159 - accuracy: 1.0000
#
# Epoch 00237: loss improved from 0.01604 to 0.01594, saving model to basic_class_32_bilinear.h5
# Epoch 238/500
# 70/70 [==============================] - 0s 210us/step - loss: 0.0158 - accuracy: 1.0000
#
# Epoch 00238: loss improved from 0.01594 to 0.01583, saving model to basic_class_32_bilinear.h5
# Epoch 239/500
# 70/70 [==============================] - 0s 175us/step - loss: 0.0157 - accuracy: 1.0000
#
# Epoch 00239: loss improved from 0.01583 to 0.01573, saving model to basic_class_32_bilinear.h5
# Epoch 240/500
# 70/70 [==============================] - 0s 191us/step - loss: 0.0156 - accuracy: 1.0000
#
# Epoch 00240: loss improved from 0.01573 to 0.01562, saving model to basic_class_32_bilinear.h5
# Epoch 241/500
# 70/70 [==============================] - 0s 209us/step - loss: 0.0155 - accuracy: 1.0000
#
# Epoch 00241: loss improved from 0.01562 to 0.01552, saving model to basic_class_32_bilinear.h5
# Epoch 242/500
# 70/70 [==============================] - 0s 213us/step - loss: 0.0154 - accuracy: 1.0000
#
# ...
# Epoch 248/500
# 70/70 [==============================] - 0s 188us/step - loss: 0.0148 - accuracy: 1.0000
#
# Epoch 00248: loss improved from 0.01493 to 0.01483, saving model to basic_class_32_bilinear.h5
# Epoch 249/500
# 70/70 [==============================] - 0s 190us/step - loss: 0.0147 - accuracy: 1.0000
#
# Epoch 00249: loss improved from 0.01483 to 0.01474, saving model to basic_class_32_bilinear.h5
# Epoch 250/500
# 70/70 [==============================] - 0s 221us/step - loss: 0.0146 - accuracy: 1.0000
#
# Epoch 00250: loss improved from 0.01474 to 0.01465, saving model to basic_class_32_bilinear.h5
# Epoch 251/500
# 70/70 [==============================] - 0s 203us/step - loss: 0.0146 - accuracy: 1.0000
#
# Epoch 00251: loss improved from 0.01465 to 0.01455, saving model to basic_class_32_bilinear.h5
# Epoch 252/500
# 70/70 [==============================] - 0s 202us/step - loss: 0.0145 - accuracy: 1.0000
#
# Epoch 00252: loss improved from 0.01455 to 0.01446, saving model to basic_class_32_bilinear.h5
# Epoch 253/500
# 70/70 [==============================] - 0s 240us/step - loss: 0.0144 - accuracy: 1.0000
#
# Epoch 00253: loss improved from 0.01446 to 0.01437, saving model to basic_class_32_bilinear.h5
# Epoch 254/500
# 70/70 [==============================] - 0s 204us/step - loss: 0.0143 - accuracy: 1.0000
#
# Epoch 00254: loss improved from 0.01437 to 0.01428, saving model to basic_class_32_bilinear.h5
# Epoch 255/500
# 70/70 [==============================] - 0s 176us/step - loss: 0.0142 - accuracy: 1.0000
#
# Epoch 00255: loss improved from 0.01428 to 0.01419, saving model to basic_class_32_bilinear.h5
# Epoch 256/500
# 70/70 [==============================] - 0s 233us/step - loss: 0.0141 - accuracy: 1.0000
#
# Epoch 00256: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00256: loss improved from 0.01419 to 0.01410, saving model to basic_class_32_bilinear.h5
# Epoch 257/500
# 70/70 [==============================] - 0s 148us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00257: loss improved from 0.01410 to 0.01402, saving model to basic_class_32_bilinear.h5
# Epoch 258/500
# 70/70 [==============================] - 0s 174us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00258: loss improved from 0.01402 to 0.01401, saving model to basic_class_32_bilinear.h5
# Epoch 259/500
# 70/70 [==============================] - 0s 195us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00259: loss improved from 0.01401 to 0.01400, saving model to basic_class_32_bilinear.h5
# Epoch 260/500
# 70/70 [==============================] - 0s 185us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00260: loss improved from 0.01400 to 0.01399, saving model to basic_class_32_bilinear.h5
# Epoch 261/500
# 70/70 [==============================] - 0s 144us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00261: loss improved from 0.01399 to 0.01398, saving model to basic_class_32_bilinear.h5
# Epoch 262/500
# 70/70 [==============================] - 0s 142us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00262: loss improved from 0.01398 to 0.01397, saving model to basic_class_32_bilinear.h5
# Epoch 263/500
# 70/70 [==============================] - 0s 207us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00263: loss improved from 0.01397 to 0.01396, saving model to basic_class_32_bilinear.h5
# Epoch 264/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.0140 - accuracy: 1.0000
#
# Epoch 00264: loss improved from 0.01396 to 0.01395, saving model to basic_class_32_bilinear.h5
# Epoch 265/500
# 70/70 [==============================] - 0s 183us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00265: loss improved from 0.01395 to 0.01395, saving model to basic_class_32_bilinear.h5
# Epoch 266/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00266: loss improved from 0.01395 to 0.01394, saving model to basic_class_32_bilinear.h5
# Epoch 267/500
# 70/70 [==============================] - 0s 230us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00267: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00267: loss improved from 0.01394 to 0.01393, saving model to basic_class_32_bilinear.h5
# Epoch 268/500
# 70/70 [==============================] - 0s 150us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00268: loss improved from 0.01393 to 0.01392, saving model to basic_class_32_bilinear.h5
# Epoch 269/500
# 70/70 [==============================] - 0s 170us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00269: loss improved from 0.01392 to 0.01392, saving model to basic_class_32_bilinear.h5
# Epoch 270/500
# 70/70 [==============================] - 0s 196us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00270: loss improved from 0.01392 to 0.01392, saving model to basic_class_32_bilinear.h5
# Epoch 271/500
# 70/70 [==============================] - 0s 211us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00271: loss improved from 0.01392 to 0.01392, saving model to basic_class_32_bilinear.h5
# Epoch 272/500
# 70/70 [==============================] - 0s 179us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00272: loss improved from 0.01392 to 0.01392, saving model to basic_class_32_bilinear.h5
# Epoch 273/500
# 70/70 [==============================] - 0s 231us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00273: loss improved from 0.01392 to 0.01392, saving model to basic_class_32_bilinear.h5
# Epoch 274/500
# 70/70 [==============================] - 0s 193us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00274: loss improved from 0.01392 to 0.01392, saving model to basic_class_32_bilinear.h5
# Epoch 275/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00275: loss improved from 0.01392 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 276/500
# 70/70 [==============================] - 0s 204us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00276: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 277/500
# 70/70 [==============================] - 0s 156us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00277: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00277: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 278/500
# 70/70 [==============================] - 0s 254us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00278: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 279/500
# 70/70 [==============================] - 0s 226us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00279: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 280/500
# 70/70 [==============================] - 0s 238us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00280: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 281/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00281: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 282/500
# 70/70 [==============================] - 0s 183us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00282: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 283/500
# 70/70 [==============================] - 0s 184us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00283: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 284/500
# 70/70 [==============================] - 0s 208us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00284: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 285/500
# 70/70 [==============================] - 0s 145us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00285: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 286/500
# 70/70 [==============================] - 0s 245us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00286: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 287/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00287: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00287: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 288/500
# 70/70 [==============================] - 0s 204us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00288: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 289/500
# 70/70 [==============================] - 0s 193us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00289: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 290/500
# 70/70 [==============================] - 0s 185us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00290: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 291/500
# 70/70 [==============================] - 0s 236us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00291: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 292/500
# 70/70 [==============================] - 0s 238us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00292: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 293/500
# 70/70 [==============================] - 0s 209us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00293: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 294/500
# 70/70 [==============================] - 0s 195us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00294: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 295/500
# 70/70 [==============================] - 0s 226us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00295: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 296/500
# 70/70 [==============================] - 0s 236us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00296: loss did not improve from 0.01391
# Epoch 297/500
# 70/70 [==============================] - 0s 197us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00297: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 00297: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 298/500
# 70/70 [==============================] - 0s 213us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00298: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 299/500
# 70/70 [==============================] - 0s 219us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00299: loss did not improve from 0.01391
# Epoch 300/500
# 70/70 [==============================] - 0s 214us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00300: loss did not improve from 0.01391
# Epoch 301/500
# 70/70 [==============================] - 0s 198us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00301: loss did not improve from 0.01391
# Epoch 302/500
# 70/70 [==============================] - 0s 176us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00302: loss improved from 0.01391 to 0.01391, saving model to basic_class_32_bilinear.h5
# Epoch 303/500
# 70/70 [==============================] - 0s 187us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00303: loss did not improve from 0.01391
# Epoch 304/500
# 70/70 [==============================] - 0s 203us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00304: loss did not improve from 0.01391
# Epoch 305/500
# 70/70 [==============================] - 0s 220us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00305: loss did not improve from 0.01391
# Epoch 306/500
# 70/70 [==============================] - 0s 197us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00306: loss did not improve from 0.01391
# Epoch 307/500
# 70/70 [==============================] - 0s 216us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00307: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 00307: loss did not improve from 0.01391
# Epoch 308/500
# 70/70 [==============================] - 0s 194us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00308: loss did not improve from 0.01391
# Epoch 309/500
# 70/70 [==============================] - 0s 225us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00309: loss did not improve from 0.01391
# Epoch 310/500
# 70/70 [==============================] - 0s 242us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00310: loss did not improve from 0.01391
# Epoch 311/500
# 70/70 [==============================] - 0s 218us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00311: loss did not improve from 0.01391
# Epoch 312/500
# 70/70 [==============================] - 0s 248us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00312: loss did not improve from 0.01391
# Epoch 313/500
# 70/70 [==============================] - 0s 195us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00313: loss did not improve from 0.01391
# Epoch 314/500
# 70/70 [==============================] - 0s 157us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00314: loss did not improve from 0.01391
# Epoch 315/500
# 70/70 [==============================] - 0s 214us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00315: loss did not improve from 0.01391
# Epoch 316/500
# 70/70 [==============================] - 0s 197us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00316: loss did not improve from 0.01391
# Epoch 317/500
# 70/70 [==============================] - 0s 188us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00317: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
#
# Epoch 00317: loss did not improve from 0.01391
# Epoch 318/500
# 70/70 [==============================] - 0s 210us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00318: loss did not improve from 0.01391
# Epoch 319/500
# 70/70 [==============================] - 0s 238us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00319: loss did not improve from 0.01391
# Epoch 320/500
# 70/70 [==============================] - 0s 200us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00320: loss did not improve from 0.01391
# Epoch 321/500
# 70/70 [==============================] - 0s 185us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00321: loss did not improve from 0.01391
# Epoch 322/500
# 70/70 [==============================] - 0s 191us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00322: loss did not improve from 0.01391
# Epoch 323/500
# 70/70 [==============================] - 0s 228us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00323: loss did not improve from 0.01391
# Epoch 324/500
# 70/70 [==============================] - 0s 193us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00324: loss did not improve from 0.01391
# Epoch 325/500
# 70/70 [==============================] - 0s 182us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00325: loss did not improve from 0.01391
# Epoch 326/500
# 70/70 [==============================] - 0s 213us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00326: loss did not improve from 0.01391
# Epoch 327/500
# 70/70 [==============================] - 0s 221us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00327: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
#
# Epoch 00327: loss did not improve from 0.01391
# Epoch 328/500
# 70/70 [==============================] - 0s 234us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00328: loss did not improve from 0.01391
# Epoch 329/500
# 70/70 [==============================] - 0s 227us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00329: loss did not improve from 0.01391
# Epoch 330/500
# 70/70 [==============================] - 0s 253us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00330: loss did not improve from 0.01391
# Epoch 331/500
# 70/70 [==============================] - 0s 221us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00331: loss did not improve from 0.01391
# Epoch 332/500
# 70/70 [==============================] - 0s 206us/step - loss: 0.0139 - accuracy: 1.0000
#
# Epoch 00332: loss did not improve from 0.01391
# Epoch 00332: early stopping

# %%
fig = plt.figure()
plt.axes(facecolor='white')
plt.plot(results.history['loss'])
# plt.plot(results.history['accuracy'])
# plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.legend(['train', 'acc'], loc='upper left')
plt.legend(['train'], loc='upper left')

plt.savefig('./result_img/basic_loss',dpi=200, facecolor='w', edgecolor='w')
plt.show()

# %%
test_results= model.predict(img_test, batch_size=128, verbose=1)
# Out:
# 32/32 [==============================] - 0s 5ms/step

# %%
fig = plt.figure()
# plt.axes(facecolor='white')
plt.plot(test_results)
plt.plot(lab_test)
plt.title('test')
plt.legend(['result', 'GT'], loc='upper left')
plt.savefig('./result_img/basic_results',dpi=200, facecolor='w', edgecolor='w')
plt.show()

# %%
score= model.evaluate(img_test, lab_test)
print("loss: %.2f, 정확도: %.2f  " %(score[0], score[1]))
# Out:
# 32/32 [==============================] - 0s 4ms/step
# loss: 0.36, 정확도: 0.88

# %%
print(test_results)
# Out:
# [[0.08221827]
#  [0.6853607 ]
#  [0.96756303]
#  [0.6781287 ]
#  [0.2569995 ]
#  [0.68844324]
#  [0.7371537 ]
#  [0.4733548 ]
#  [0.14494552]
#  [0.10483782]
#  [0.1590604 ]
#  [0.162387  ]
#  [0.17393841]
#  [0.22595592]
#  [0.09842465]
#  [0.11865533]
#  [0.96987176]
#  [0.9304713 ]
#  [0.87122995]
#  [0.957238  ]
#  [0.9576315 ]
#  [0.97235537]
#  [0.96468663]
#  [0.94075394]
#  [0.95387006]
#  [0.9525789 ]
#  [0.9122054 ]
#  [0.9535953 ]
#  [0.9481868 ]
#  [0.95237774]
#  [0.89303243]
#  [0.9122671 ]]

# %%
for i in range(len(img_test)):
    if i<16:
#         label= 'label: 0'
        if test_results[i]<0.5:

            plt.figure()
            plt.title("num:"+ str(i)+', label: 0, probability:'+str(test_results[i])+ ', result: 0, abnormal')
            plt.imshow(img_test[i,:,:,0],cmap='gray')
            plt.savefig('./result_img/basic/'+str(i),dpi=200, facecolor='w', edgecolor='w')
            
        else:

            plt.figure()
            plt.title("num:"+ str(i)+', label: 0, probability:'+str(test_results[i])+ ', result: 1, normal')
            plt.imshow(img_test[i,:,:,0],cmap='gray')
            plt.savefig('./result_img/basic/'+str(i),dpi=200, facecolor='w', edgecolor='w')
            
    else:
        label= 'label: 1'
        if test_results[i]<0.5:

            plt.figure()
            plt.title("num:"+ str(i)+', label: 1, probability:'+str(test_results[i])+ ', result: 0, abnormal')
            plt.imshow(img_test[i,:,:,0],cmap='gray')
            plt.savefig('./result_img/basic/'+str(i),dpi=200, facecolor='w', edgecolor='w')
            
        else:

            plt.figure()
            plt.title("num:"+ str(i)+', label: 1, probability:'+str(test_results[i])+ ', result: 1, normal')
            plt.imshow(img_test[i,:,:,0],cmap='gray')
            plt.savefig('./result_img/basic/'+str(i),dpi=200, facecolor='w', edgecolor='w')
# Out:
# /home/ubuntu/anaconda3/envs/zzaem1/lib/python3.6/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
