# %%
import cv2
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import SimpleITK as sitk

from  scipy import ndimage

from skimage.io import imread, imshow
from skimage import *
import skimage

# %%
#########cv2 area로 다리2개 좌표 찾기
img = cv2.imread('seg_test.jpg')

gray1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray1)
img1 = img.copy()

ret, thresh = cv2.threshold(gray1,127,255,0)

contours, hierachy = cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

print('length of contours:',len(contours))
areas=[]
conloc=[]

legs=[]
for cnt in range(len(contours)):    
    area=cv2.contourArea(contours[cnt])
    areas.append(area)
    conloc.append(contours[cnt])

legs.append(areas.index(max(areas)))
print(areas, 'max:' ,max(areas))            
sec=areas[0]
for fsec in range(1, len(conloc)):
#     print(conloc[fsec])
    if len(conloc)==0 or len(conloc)==1:
        print('check file')
    
    else:
        if areas[fsec]>sec and areas[fsec]< max(areas):
                print('area[fsec]:', areas[fsec])
                sec=areas[fsec]
legs.append(areas.index(sec))
    
    
for tc in range(len(legs)):
    x, y, w, h = cv2.boundingRect(contours[legs[tc]])
    print(x, y, w, h)

    dd=cv2.rectangle(img1,(x,y),(x+w,y+h), (0, 255, 0), 1)

plt.figure(figsize=(20,20))
plt.imshow(img1, cmap='gray')
# Out:
# length of contours: 10
# [5.0, 23.5, 58.5, 21871.5, 2.0, 4.0, 2.0, 2.0, 2.0, 21934.0] max: 21934.0
# area[fsec]: 23.5
# area[fsec]: 58.5
# area[fsec]: 21871.5
# 251 190 185 152
# 64 196 182 149

# %%
gray = hole[0].astype(np.uint8) 
gray += 1
gray[gray==2] = 0

img = hole[0].astype(np.uint8) 

#gray1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.uint8(img)
# img1 = img.copy()

#ret, thresh = cv2.threshold(gray,127,255,0)

contours, hierachy = cv2.findContours(gray, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
print(len(contours))

for tc in range(len(contours)):
    x, y, w, h = cv2.boundingRect(contours[tc])

# %%
###########################
def win_scale(data, wl, ww, dtype, out_range):
    """
    Scale pixel intensity data using specified window level, width, and intensity range.
    """
    
    data_new = np.empty(data.shape, dtype=np.double)
    data_new.fill(out_range[1]-1)
    
    data_new[data <= (wl-ww/2.0)] = out_range[0]
    
    data_new[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))] = ((data[(data>(wl-ww/2.0))&(data<=(wl+ww/2.0))]-(wl-0.5))/(ww-1.0)+0.5)*(out_range[1]-out_range[0])+out_range[0]
    
    data_new[data > (wl+ww/2.0)] = out_range[1]-1
    
    return data_new.astype(dtype)

# %%
dcm_list=sorted(glob.glob('../data/dvt/01013843/*.dcm'))
dcm_name=sorted(os.listdir('../data/dvt/01013843'))
img_T1 = sitk.ReadImage(dcm_list)
# print(img_T1)
img_array=sitk.GetArrayFromImage(img_T1)
print(img_array.min(), img_array.max())
img_array = win_scale(img_array, 60, 400, np.uint8, (0, 255))

print(img_array.min(), img_array.max())


img_array[img_array > 0] = 255
img_array[img_array <= 0] = 0
        
img_array=ndimage.binary_closing(img_array).astype(np.uint8)
img_array=ndimage.binary_fill_holes(img_array).astype(np.uint8)

img_T1=sitk.GetImageFromArray(img_array)
# Out:
# -1024 3071
# 0 255

# %%
img_names=[]
for ddd in dcm_name:
    if ddd.endswith('.dcm'):
        img_names.append(ddd[:ddd.rindex('.dcm')])

# %%
print(img_names)
# Out:
# ['01013843_0000', '01013843_0001', '01013843_0002', '01013843_0003', '01013843_0004', '01013843_0005', '01013843_0006', '01013843_0007', '01013843_0008', '01013843_0009', '01013843_0010', '01013843_0011', '01013843_0012', '01013843_0013', '01013843_0014', '01013843_0015', '01013843_0016', '01013843_0017', '01013843_0018', '01013843_0019', '01013843_0020', '01013843_0021', '01013843_0022', '01013843_0023', '01013843_0024', '01013843_0025', '01013843_0026', '01013843_0027', '01013843_0028', '01013843_0029', '01013843_0030', '01013843_0031', '01013843_0032', '01013843_0033', '01013843_0034', '01013843_0035', '01013843_0036', '01013843_0037', '01013843_0038', '01013843_0039', '01013843_0040', '01013843_0041', '01013843_0042', '01013843_0043', '01013843_0044', '01013843_0045', '01013843_0046', '01013843_0047', '01013843_0048', '01013843_0049', '01013843_0050', '01013843_0051', '01013843_0052', '01013843_0053', '01013843_0054', '01013843_0055', '01013843_0056', '01013843_0057', '01013843_0058', '01013843_0059', '01013843_0060', '01013843_0061', '01013843_0062', '01013843_0063', '01013843_0064', '01013843_0065', '01013843_0066', '01013843_0067', '01013843_0068', '01013843_0069', '01013843_0070', '01013843_0071', '01013843_0072', '01013843_0073', '01013843_0074', '01013843_0075', '01013843_0076', '01013843_0077', '01013843_0078', '01013843_0079', '01013843_0080', '01013843_0081', '01013843_0082', '01013843_0083', '01013843_0084', '01013843_0085', '01013843_0086', '01013843_0087', '01013843_0088', '01013843_0089', '01013843_0090', '01013843_0091', '01013843_0092', '01013843_0093', '01013843_0094', '01013843_0095', '01013843_0096', '01013843_0097', '01013843_0098', '01013843_0099', '01013843_0100', '01013843_0101', '01013843_0102', '01013843_0103', '01013843_0104', '01013843_0105', '01013843_0106', '01013843_0107', '01013843_0108', '01013843_0109', '01013843_0110', '01013843_0111', '01013843_0112', '01013843_0113', '01013843_0114', '01013843_0115', '01013843_0116', '01013843_0117', '01013843_0118', '01013843_0119', '01013843_0120', '01013843_0121', '01013843_0122', '01013843_0123', '01013843_0124', '01013843_0125', '01013843_0126', '01013843_0127', '01013843_0128', '01013843_0129', '01013843_0130', '01013843_0131', '01013843_0132', '01013843_0133', '01013843_0134', '01013843_0135', '01013843_0136', '01013843_0137', '01013843_0138', '01013843_0139', '01013843_0140', '01013843_0141', '01013843_0142', '01013843_0143', '01013843_0144', '01013843_0145', '01013843_0146', '01013843_0147', '01013843_0148', '01013843_0149', '01013843_0150', '01013843_0151', '01013843_0152', '01013843_0153', '01013843_0154', '01013843_0155', '01013843_0156', '01013843_0157', '01013843_0158', '01013843_0159', '01013843_0160', '01013843_0161', '01013843_0162', '01013843_0163', '01013843_0164', '01013843_0165', '01013843_0166', '01013843_0167', '01013843_0168', '01013843_0169', '01013843_0170', '01013843_0171', '01013843_0172', '01013843_0173', '01013843_0174', '01013843_0175', '01013843_0176', '01013843_0177', '01013843_0178', '01013843_0179', '01013843_0180', '01013843_0181', '01013843_0182', '01013843_0183', '01013843_0184', '01013843_0185', '01013843_0186', '01013843_0187', '01013843_0188', '01013843_0189', '01013843_0190', '01013843_0191', '01013843_0192', '01013843_0193', '01013843_0194', '01013843_0195', '01013843_0196', '01013843_0197', '01013843_0198', '01013843_0199', '01013843_0200', '01013843_0201', '01013843_0202', '01013843_0203', '01013843_0204', '01013843_0205', '01013843_0206', '01013843_0207', '01013843_0208', '01013843_0209', '01013843_0210', '01013843_0211', '01013843_0212', '01013843_0213', '01013843_0214', '01013843_0215', '01013843_0216', '01013843_0217', '01013843_0218', '01013843_0219', '01013843_0220', '01013843_0221', '01013843_0222', '01013843_0223', '01013843_0224', '01013843_0225', '01013843_0226', '01013843_0227', '01013843_0228', '01013843_0229', '01013843_0230', '01013843_0231', '01013843_0232', '01013843_0233', '01013843_0234', '010 ...

# %%
img_T1_255 = sitk.Cast(sitk.RescaleIntensity(img_T1), sitk.sitkUInt8)

seed = (250,250,68)
seg = sitk.Image(img_T1.GetSize(), sitk.sitkUInt8)
seg.CopyInformation(img_T1)
seg[seed] = 1

# %%
seg = sitk.ConfidenceConnected(img_T1, seedList=[seed],
                                   numberOfIterations=4,
                                   multiplier=2.5,
                                   initialNeighborhoodRadius=1,
                                   replaceValue=1)

# %%
# imgData = sitk.GetArrayFromImage(seg)
# hole=ndimage.binary_closing(imgData).astype(np.uint8)
# hole=ndimage.binary_fill_holes(hole).astype(np.uint8)
hole=sitk.GetArrayFromImage(seg)

# %%
i=0
for one_p in range(len(hole)):
# for one_p in range(200,201):
# i=0
# for one_p in range(4):
    print('next')
    img = hole[one_p]
    gray = np.uint8(img)
#     gray += 1
#     gray[gray==2] = 0
    img1 = gray.copy()

    
    contours, hierachy = cv2.findContours(img1, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    
#     zero = np.zeros([512,512,3], dtype=np.uint8)

# #     zero[:,:,0],zero[:,:,1],zero[:,:,2] = img[:,:], img[:,:], img[:,:]

# #     zero[:,:,1] = img1
# #     zero[:,:,2] = img1

#     img2 = zero
    
####################
#     print('length of contours:',len(contours))
    areas=[]
    conloc=[]

    legs=[]
    if len(contours)==0:
        print('no contours', one_p)
        i+=1
        continue
    else:
        for cnt in range(len(contours)):    
            area=cv2.contourArea(contours[cnt])
            areas.append(area)
            conloc.append(contours[cnt])
            x, y, w, h = cv2.boundingRect(contours[cnt])
    #         print(x, y, w, h)
            cv2.rectangle(img1,(x,y),(x+w,y+h), (0, 255, 0),2)
        print('one_p번째:', one_p,'번째')
#     print(areas)
#     print(max(areas),max(areas)-1000.0)
    legs.append(areas.index(max(areas)))
#     print(areas, 'max:' ,max(areas))
#     print(areas)
    sec=areas[0]
    
    for fsec in range(0, len(conloc)):
#         print(conloc[fsec])

        if (areas[fsec]!=max(areas)) and (areas[fsec]> max(areas)-1000.0):
            legs.append(areas.index(areas[fsec]))
        
#             print('area[fsec]:', areas[fsec])
#             sec=areas[fsec]
#     if sec<max(areas)-1000.0:
#         legs.append(areas.index(sec))
        else:
#             print(one_p,': abdomen')
            pass
    
    print('legs:',len(legs), legs)


    for tc in range(len(legs)):
        x, y, w, h = cv2.boundingRect(contours[legs[tc]])
        cv2.rectangle(img2,(x,y),(x+w,y+h), (0, 255, 0), 2)
    print('다음:',one_p+i)
###########################    
    crop_img=
    
    io.imsave('../data/try5/test'+'/'+ img_names[one_p]+'.png', crop_img)
    

#     plt.figure(figsize=(10,10))
# # #     print('number:', match_int[oi])
#     plt.subplot(1,2,1)
#     plt.imshow(img1, cmap='gray')
    
#     plt.subplot(1,1,1)
#     plt.imshow(img2, cmap='gray')
# Out:
# next
# no contours 0
# next
# one_p번째: 1 번째
# legs: 1 [1]
# 다음: 2
# next
# one_p번째: 2 번째
# legs: 1 [1]
# 다음: 3
# next
# one_p번째: 3 번째
# legs: 1 [1]
# 다음: 4
# next
# one_p번째: 4 번째
# legs: 1 [1]
# 다음: 5
# next
# one_p번째: 5 번째
# legs: 1 [1]
# 다음: 6
# next
# one_p번째: 6 번째
# legs: 1 [1]
# 다음: 7
# next
# one_p번째: 7 번째
# legs: 1 [1]
# 다음: 8
# next
# one_p번째: 8 번째
# legs: 1 [1]
# 다음: 9
# next
# one_p번째: 9 번째
# legs: 1 [1]
# 다음: 10
# next
# one_p번째: 10 번째
# legs: 1 [1]
# 다음: 11
# next
# one_p번째: 11 번째
# legs: 1 [1]
# 다음: 12
# next
# one_p번째: 12 번째
# legs: 1 [1]
# 다음: 13
# next
# one_p번째: 13 번째
# legs: 1 [1]
# 다음: 14
# next
# one_p번째: 14 번째
# legs: 1 [1]
# 다음: 15
# next
# one_p번째: 15 번째
# legs: 1 [1]
# 다음: 16
# next
# one_p번째: 16 번째
# legs: 1 [1]
# 다음: 17
# next
# one_p번째: 17 번째
# legs: 1 [1]
# 다음: 18
# next
# one_p번째: 18 번째
# legs: 1 [1]
# 다음: 19
# next
# one_p번째: 19 번째
# legs: 1 [1]
# 다음: 20
# next
# one_p번째: 20 번째
# legs: 1 [1]
# 다음: 21
# next
# one_p번째: 21 번째
# legs: 1 [1]
# 다음: 22
# next
# one_p번째: 22 번째
# legs: 1 [1]
# 다음: 23
# next
# one_p번째: 23 번째
# legs: 1 [1]
# 다음: 24
# next
# one_p번째: 24 번째
# legs: 1 [1]
# 다음: 25
# next
# one_p번째: 25 번째
# legs: 1 [1]
# 다음: 26
# next
# one_p번째: 26 번째
# legs: 1 [1]
# 다음: 27
# next
# one_p번째: 27 번째
# legs: 1 [1]
# 다음: 28
# next
# one_p번째: 28 번째
# legs: 1 [1]
# 다음: 29
# next
# one_p번째: 29 번째
# legs: 1 [1]
# 다음: 30
# next
# one_p번째: 30 번째
# legs: 1 [1]
# 다음: 31
# next
# one_p번째: 31 번째
# legs: 1 [1]
# 다음: 32
# next
# one_p번째: 32 번째
# legs: 1 [1]
# 다음: 33
# next
# one_p번째: 33 번째
# legs: 1 [1]
# 다음: 34
# next
# one_p번째: 34 번째
# legs: 1 [1]
# 다음: 35
# next
# one_p번째: 35 번째
# legs: 1 [1]
# 다음: 36
# next
# one_p번째: 36 번째
# legs: 1 [1]
# 다음: 37
# next
# one_p번째: 37 번째
# legs: 1 [1]
# 다음: 38
# next
# one_p번째: 38 번째
# legs: 1 [1]
# 다음: 39
# next
# one_p번째: 39 번째
# legs: 1 [1]
# 다음: 40
# next
# one_p번째: 40 번째
# legs: 1 [1]
# 다음: 41
# next
# one_p번째: 41 번째
# legs: 1 [1]
# 다음: 42
# next
# one_p번째: 42 번째
# legs: 1 [1]
# 다음: 43
# next
# one_p번째: 43 번째
# legs: 1 [1]
# 다음: 44
# next
# one_p번째: 44 번째
# legs: 1 [1]
# 다음: 45
# next
# one_p번째: 45 번째
# legs: 1 [1]
# 다음: 46
# next
# one_p번째: 46 번째
# legs: 1 [1]
# 다음: 47
# next
# one_p번째: 47 번째
# legs: 1 [1]
# 다음: 48
# next
# one_p번째: 48 번째
# legs: 1 [1]
# 다음: 49
# next
# one_p번째: 49 번째
# legs: 1 [1]
# 다음: 50
# next
# one_p번째: 50 번째
# legs: 1 [1]
# 다음: 51
# next
# one_p번째: 51 번째
# legs: 1 [1]
# 다음: 52
# next
# one_p번째: 52 번째
# legs: 1 [0]
# 다음: 53
# next
# one_p번째: 53 번째
# legs: 1 [0]
# 다음: 54
# next
# one_p번째: 54 번째
# legs: 1 [1]
# 다음: 55
# next
# one_p번째: 55 번째
# legs: 1 [0]
# 다음: 56
# next
# one_p번째: 56 번째
# legs: 1 [0]
# 다음: 57
# next
# one_p번째: 57 번째
# legs: 1 [0]
# 다음: 58
# next
# one_p번째: 58 번째
# legs: 1 [0]
# 다음: 59
# next
# one_p번째: 59 번째
# legs: 1 [0]
# 다음: 60
# next
# one_p번째: 60 번째
# legs: 1 [0]
# 다음: 61
# next
# one_p번째: 61 번째
# legs: 1 [0]
# 다음: 62
# next
# one_p번째: 62 번째
# legs: 1 [0]
# 다음: 63
# next
# one_p번째: 63 번째
# legs: 1 [0]
# 다음: 64
# next
# one_p번째: 64 번째
# legs: 1 [0]
# 다음: 65
# next
# one_p번째: 65 번째
# legs: 1 [0]
# 다음: 66
# next
# one_p번째: 66 번째
# legs: 1 [1]
# 다음: 67
# next
# one_p번째: 67 번째
# legs: 1 [1]
# 다음: 68
# next
# one_p번째: 68 번째
# legs: 1 [1]
# 다음: 69
# next
# one_p번째: 69 번째
# legs: 1 [1]
# 다음: 70
# next
# one_p번째: 70 번째
# legs: 1 [1]
# 다음: 71
# next
# one_p번째: 71 번째
# legs: 1 [1]
# 다음: 72
# next
# one_p번째: 72 번째
# legs: 1 [1]
# 다음: 73
# next
# one_p번째: 73 번째
# legs: 1 [1]
# 다음: 74
# next
# one_p번째: 74 번째
# legs: 1 [1]
# 다음: 75
# next
# one_p번째: 75 번째
# legs: 1 [1]
# 다음: 76
# next
# one_p번째: 76 번째
# legs: 1 [1]
# 다음: 77
# next
# one_p번째: 77 번째
# legs: 1 [1]
# 다음: 78
# next
# one_p번째: 78 번째
# legs: 1 [1]
# 다음: 79
# next
# one_p번째: 79 번째
# legs: 1 [1]
# 다음: 80
# next
# one_p번째: 80 번째
# legs: 1 [2]
# 다음: 81
# next
# one_p번째: 81 번째
# legs: 1 [2]
# 다음: 82
# next
# one_p번째: 82 번째
# legs: 1 [2]
# 다음: 83
# next
# one_p번째: 83 번째
# legs: 1 [2]
# 다음: 84
# next
# one_p번째: 84 번째
# legs: 1 [1]
# 다음: 85
# next
# one_p번째: 85 번째
# legs: 2 [2, 1]
# 다음: 86
# next
# one_p번째: 86 번째
# legs: 2 [2, 1]
# 다음: 87
# next
# one_p번째: 87 번째
# legs: 2 [2, 3]
# 다음: 88
# next
# one_p번째: 88 번째
# legs: 2 [3, 4]
# 다음: 89
# next
# one_p번째: 89 번째
# legs: 1 [1]
# 다음: 90
# next
# one_p번째: 90 번째
# legs: 2 [2, 4]
# 다음: 91
# next
# one_p번째: 91 번째
# legs: 2 [2, 3]
# 다음: 92
# next
# one_p번째: 92 번째
# legs: 2 [2, 3]
# 다음: 93
# next
# one_p번째: 93 번째
# legs: 2 [3, 4]
# 다음: 94
# next
# one_p번째: 94 번째
# legs: 2 [2, 3]
# 다음: 95
# next
# one_p번째: 95 번째
# legs: 2 [1, 2]
# 다음: 96
# next
# one_p번째: 96 번째
# legs: 2 [0, 1]
# 다음: 97
# next
# one_p번째: 97 번째
# legs: 2 [0, 1]
# 다음: 98
# next
# one_p번째: 98 번째
# legs: 2 [0, 1]
# 다음: 99
# next
# one_p번째: 99 번째
# legs: 2 [1, 0]
# 다음: 100
# next
# one_p번째: 100 번째
# legs: 2 [1, 0]
# 다음: 101
# next
# one_p번째: 101 번째
# legs: 2 [1, 0]
# 다음: 102
# next
# one_p번째: 102 번째
# legs: 2 [1, 0]
# 다음: 103
# next
# one_p번째: 103 번째
# legs: 2 [1, 0]
# 다음: 104
# next
# one_p번째: 104 번째
# legs: 2 [1, 0]
# 다음: 105
# next
# one_p번째: 105 번째
# legs: 2 [1, 0]
# 다음: 106
# next
# one_p번째: 106 번째
# legs: 2 [1, 0]
# 다음: 107
# next
# one_p번째: 107 번째
# legs: 2 [1, 0]
# 다음: 108
# next
# one_p번째: 108 번째
# legs: 2 [1, 0]
# 다음: 109
# next
# one_p번째: 109 번째
# legs: 2 [1, 0]
# 다음: 110
# next
# one_p번째: 110 번째
# legs: 2 [1, 0]
# 다음: 111
# next
# one_p번째: 111 번째
# legs: 2 [1, 0]
# 다음: 112
# next
# one_p번째: 112 번째
# legs: 2 [1, 0]
# 다음: 113
# next
# one_p번째: 113 번째
# legs: 2 [1, 0]
# 다음: 114
# next
# one_p번째: 114 번째
# legs: 2 [1, 0]
# 다음: 115
# next
# one_p번째: 115 번째
# legs: 2 [1, 0]
# 다음: 116
# next
# one_p번째: 116 번째
# legs: 2 [1, 0]
# 다음: 117
# next
# one_p번째: 117 번째
# legs: 2 [1, 0]
# 다음: 118
# next
# one_p번째: 118 번째
# legs: 2 [1, 0]
# 다음: 119
# next
# one_p번째: 119 번째
# legs: 2 [1, 0]
# 다음: 120
# next
# one_p번째: 120 번째
# legs: 2 [1, 0]
# 다음: 121
# next
# one_p번째: 121 번째
# legs: 2 [1, 0]
# 다음: 122
# next
# one_p번째: 122 번째
# legs: 2 [1, 0]
# 다음: 123
# next
# one_p번째: 123 번째
# legs: 2 [1, 0]
# 다음: 124
# next
# one_p번째: 124 번째
# legs: 2 [1, 0]
# 다음: 125
# next
# one_p번째: 125 번째
# legs: 2 [1, 0]
# 다음: 126
# next
# one_p번째: 126 번째
# legs: 2 [1, 0]
# 다음: 127
# next
# one_p번째: 127 번째
# legs: 2 [1, 0]
# 다음: 128
# next
# one_p번째: 128 번째
# legs: 2 [1, 0]
# 다음: 129
# next
# one_p번째: 129 번째
# legs: 2 [1, 0]
# 다음: 130
# next
# one_p번째: 130 번째
# legs: 2 [1, 0]
# 다음: 131
# next
# one_p번째: 131 번째
# legs: 2 [1, 0]
# 다음: 132
# next
# one_p번째: 132 번째
# legs: 2 [1, 0]
# 다음: 133
# next
# one_p번째: 133 번째
# legs: 2 [1, 0]
# 다음: 134
# next
# one_p번째: 134 번째
# legs: 1 [1]
# 다음: 135
# next
# one_p번째: 135 번째
# legs: 2 [7, 1]
# 다음: 136
# next
# one_p번째: 136 번째
# legs: 2 [10, 5]
# 다음: 137
# next
# one_p번째: 137 번째
# legs: 2 [8, 4]
# 다음: 138
# next
# one_p번째: 138 번째
# legs: 2 [9, 6]
# 다음: 139
# next
# one_p번째: 139 번째
# legs: 2 [5, 4]
# 다음: 140
# next
# one_p번째: 140 번째
# legs: 1 [6]
# 다음: 141
# next
# one_p번째: 141 번째
# legs: 1 [6]
# 다음: 142
# next
# one_p번째: 142 번째
# legs: 1 [11]
# 다음: 143
# next
# one_p번째: 143 번째
# legs: 1 [8]
# 다음: 144
# next
# one_p번째: 144 번째
# legs: 1 [13]
# 다음: 145
# next
# one_p번째: 145 번째
# legs: 1 [9]
# 다음: 146
# next
# one_p번째: 146 번째
# legs: 1 [9]
# 다음: 147
# next
# one_p번째: 147 번째
# legs: 1 [5]
# 다음: 148
# next
# one_p번째: 148 번째
# legs: 1 [4]
# 다음: 149
# next
# one_p번째: 149 번째
# legs: 2 [9, 0]
# 다음: 150
# next
# one_p번째: 150 번째
# legs: 2 [6, 0]
# 다음: 151
# next
# one_p번째: 151 번째
# legs: 2 [4, 0]
# 다음: 152
# next
# one_p번째: 152 번째
# legs: 2 [6, 0]
# 다음: 153
# next
# one_p번째: 153 번째
# legs: 2 [1, 0]
# 다음: 154
# next
# one_p번째: 154 번째
# legs: 2 [1, 0]
# 다음: 155
# next
# one_p번째: 155 번째
# legs: 2 [1, 0]
# 다음: 156
# next
# one_p번째: 156 번째
# legs: 2 [1, 0]
# 다음: 157
# next
# one_p번째: 157 번째
# legs: 2 [1, 0]
# 다음: 158
# next
# one_p번째: 158 번째
# legs: 2 [1, 0]
# 다음: 159
# next
# one_p번째: 159 번째
# legs: 2 [1, 0]
# 다음: 160
# next
# one_p번째: 160 번째
# legs: 2 [1, 0]
# 다음: 161
# next
# one_p번째: 161 번째
# legs: 2 [0, 1]
# 다음: 162
# next
# one_p번째: 162 번째
# legs: 2 [1, 0]
# 다음: 163
# next
# one_p번째: 163 번째
# legs: 2 [1, 0]
# 다음: 164
# next
# one_p번째: 164 번째
# legs: 2 [0, 1]
# 다음: 165
# next
# one_p번째: 165 번째
# legs: 2 [0, 1]
# 다음: 166
# next
# one_p번째: 166 번째
# legs: 2 [0, 1]
# 다음: 167
# next
# one_p번째: 167 번째
# legs: 2 [0, 1]
# 다음: 168
# next
# one_p번째: 168 번째
# legs: 2 [0, 1]
# 다음: 169
# next
# one_p번째: 169 번째
# legs: 2 [0, 1]
# 다음: 170
# next
# one_p번째: 170 번째
# legs: 2 [0, 1]
# 다음: 171
# next
# one_p번째: 171 번째
# legs: 2 [0, 1]
# 다음: 172
# next
# one_p번째: 172 번째
# legs: 2 [1, 0]
# 다음: 173
# next
# one_p번째: 173 번째
# legs: 2 [1, 0]
# 다음: 174
# next
# one_p번째: 174 번째
# legs: 2 [1, 0]
# 다음: 175
# next
# one_p번째: 175 번째
# legs: 2 [1, 0]
# 다음: 176
# next
# one_p번째: 176 번째
# legs: 2 [1, 0]
# 다음: 177
# next
# one_p번째: 177 번째
# legs: 2 [1, 0]
# 다음: 178
# next
# one_p번째: 178 번째
# legs: 2 [1, 0]
# 다음: 179
# next
# one_p번째: 179 번째
# legs: 2 [1, 0]
# 다음: 180
# next
# one_p번째: 180 번째
# legs: 2 [0, 1]
# 다음: 181
# next
# one_p번째: 181 번째
# legs: 2 [0, 1]
# 다음: 182
# next
# one_p번째: 182 번째
# legs: 2 [0, 1]
# 다음: 183
# next
# one_p번째: 183 번째
# legs: 2 [0, 1]
# 다음: 184
# next
# one_p번째: 184 번째
# legs: 2 [0, 1]
# 다음: 185
# next
# one_p번째: 185 번째
# legs: 2 [0, 1]
# 다음: 186
# next
# one_p번째: 186 번째
# legs: 2 [0, 1]
# 다음: 187
# next
# one_p번째: 187 번째
# legs: 2 [1, 0]
# 다음: 188
# next
# one_p번째: 188 번째
# legs: 2 [1, 0]
# 다음: 189
# next
# one_p번째: 189 번째
# legs: 2 [1, 0]
# 다음: 190
# next
# one_p번째: 190 번째
# legs: 2 [1, 0]
# 다음: 191
# next
# one_p번째: 191 번째
# legs: 2 [1, 0]
# 다음: 192
# next
# one_p번째: 192 번째
# legs: 2 [1, 0]
# 다음: 193
# next
# one_p번째: 193 번째
# legs: 2 [1, 0]
# 다음: 194
# next
# one_p번째: 194 번째
# legs: 2 [1, 0]
# 다음: 195
# next
# one_p번째: 195 번째
# legs: 2 [1, 0]
# 다음: 196
# next
# one_p번째: 196 번째
# legs: 2 [1, 0]
# 다음: 197
# next
# one_p번째: 197 번째
# legs: 2 [0, 1]
# 다음: 198
# next
# one_p번째: 198 번째
# legs: 2 [0, 1]
# 다음: 199
# next
# one_p번째: 199 번째
# legs: 2 [0, 1]
# 다음: 200
# next
# one_p번째: 200 번째
# legs: 2 [1, 0]
# 다음: 201
# next
# one_p번째: 201 번째
# legs: 2 [1, 0]
# 다음: 202
# next
# one_p번째: 202 번째
# legs: 2 [1, 0]
# 다음: 203
# next
# one_p번째: 203 번째
# legs: 2 [1, 0]
# 다음: 204
# next
# one_p번째: 204 번째
# legs: 2 [1, 0]
# 다음: 205
# next
# one_p번째: 205 번째
# legs: 2 [1, 0]
# 다음: 206
# next
# one_p번째: 206 번째
# legs: 2 [1, 0]
# 다음: 207
# next
# one_p번째: 207 번째
# legs: 2 [1, 0]
# 다음: 208
# next
# one_p번째: 208 번째
# legs: 2 [1, 0]
# 다음: 209
# next
# one_p번째: 209 번째
# legs: 2 [1, 0]
# 다음: 210
# next
# one_p번째: 210 번째
# legs: 2 [1, 0]
# 다음: 211
# next
# one_p번째: 211 번째
# legs: 2 [1, 0]
# 다음: 212
# next
# one_p번째: 212 번째
# legs: 2 [1, 0]
# 다음: 213
# next
# one_p번째: 213 번째
# legs: 1 [0]
# 다음: 214
# next
# one_p번째: 214 번째
# legs: 1 [0]
# 다음: 215
# next
# one_p번째: 215 번째
# legs: 1 [0]
# 다음: 216
# next
# one_p번째: 216 번째
# legs: 2 [0, 1]
# 다음: 217
# next
# one_p번째: 217 번째
# legs: 2 [1, 0]
# 다음: 218
# next
# one_p번째: 218 번째
# legs: 2 [1, 0]
# 다음: 219
# next
# one_p번째: 219 번째
# legs: 2 [1, 0]
# 다음: 220
# next
# one_p번째: 220 번째
# legs: 2 [1, 0]
# 다음: 221
# next
# one_p번째: 221 번째
# legs: 2 [1, 0]
# 다음: 222
# next
# one_p번째: 222 번째
# legs: 2 [1, 0]
# 다음: 223
# next
# one_p번째: 223 번째
# legs: 2 [2, 1]
# 다음: 224
# next
# one_p번째: 224 번째
# legs: 2 [1, 0]
# 다음: 225
# next
# one_p번째: 225 번째
# legs: 2 [1, 0]
# 다음: 226
# next
# one_p번째: 226 번째
# legs: 2 [1, 0]
# 다음: 227
# next
# one_p번째: 227 번째
# legs: 2 [1, 0]
# 다음: 228
# next
# one_p번째: 228 번째
# legs: 2 [1, 0]
# 다음: 229
# next
# one_p번째: 229 번째
# legs: 2 [1, 0]
# 다음: 230
# next
# one_p번째: 230 번째
# legs: 2 [1, 0]
# 다음: 231
# next
# one_p번째: 231 번째
# legs: 2 [1, 0]
# 다음: 232
# next
# one_p번째: 232 번째
# legs: 2 [1, 0]
# 다음: 233
# next
# one_p번째: 233 번째
# legs: 2 [1, 0]
# 다음: 234
# next
# one_p번째: 234 번째
# legs: 2 [2, 0]
# 다음: 235
# next
# one_p번째: 235 번째
# legs: 2 [3, 0]
# 다음: 236
# next
# one_p번째: 236 번째
# legs: 1 [3]
# 다음: 237
# next
# one_p번째: 237 번째
# legs: 5 [4, 0, 1, 2, 3]
# 다음: 238
# next
# one_p번째: 238 번째
# legs: 2 [1, 0]
# 다음: 239
# next
# no contours 239
# next
# no contours 240
# next
# no contours 241
# next
# no contours 242
# next
# no contours 243
# next
# no contours 244

# %%
print(img1.shape, img2.shape, img3.shape, zero.shape, img.shape)
# Out:
# (512, 512) (512, 512, 3) (512, 512) (512, 512, 3) (512, 512)

# %%
dcm_list=glob.glob('../data/dvt/01013843/*.dcm')
img_T1 = sitk.ReadImage(dcm_list)
# print(img_T1)
img_array=sitk.GetArrayFromImage(img_T1)
print(img_array.min(), img_array.max())
img_array = win_scale(img_array, 60, 400, np.uint8, (0, 255))

print(img_array.min(), img_array.max())


img_array[img_array > 0] = 255
img_array[img_array <= 0] = 0
        
img_array=ndimage.binary_closing(img_array).astype(np.uint8)
img_array=ndimage.binary_fill_holes(img_array).astype(np.uint8)

img_T1=sitk.GetImageFromArray(img_array)

img_T1_255 = sitk.Cast(sitk.RescaleIntensity(img_T1), sitk.sitkUInt8)

seed = (250,250,68)
seg = sitk.Image(img_T1.GetSize(), sitk.sitkUInt8)
seg.CopyInformation(img_T1)
seg[seed] = 1

seg = sitk.ConfidenceConnected(img_T1, seedList=[seed],
                                   numberOfIterations=4,
                                   multiplier=2.5,
                                   initialNeighborhoodRadius=1,
                                   replaceValue=1)

hole=sitk.GetArrayFromImage(seg)

# for one_p in range(len(hole)):
for one_p in range(68,69):
    img = hole[one_p].astype(np.uint8)
    img2= img.copy()
    gray = np.uint8(img)
#     gray += 1
#     gray[gray==2] = 0
    img1 = gray.copy()

    
    contours, hierachy = cv2.findContours(img1, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    
    zero = np.zeros([512,512,3], dtype=np.uint8)

    zero[:,:,0] = img1
    zero[:,:,1] = img1
    zero[:,:,2] = img1

    img1 = zero

#     print('length of contours:',len(contours))
    areas=[]
    conloc=[]

    legs=[]
    
    for cnt in range(len(contours)):    
        area=cv2.contourArea(contours[cnt])
        areas.append(area)
        conloc.append(contours[cnt])
        
        x, y, w, h = cv2.boundingRect(contours[cnt])
#         print(x, y, w, h)
        cv2.rectangle(img2,(x,y),(x+w,y+h), (0, 255, 0),2)        

    legs.append(areas.index(max(areas)))
#     print(areas, 'max:' ,max(areas))            
    sec=areas[0]
    for fsec in range(1, len(conloc)):
    #     print(conloc[fsec])
        if len(conloc)==0 or len(conloc)==1:
            print('check file')

        else:
            if areas[fsec]>sec and areas[fsec]< max(areas):
                    print('area[fsec]:', areas[fsec])
                    sec=areas[fsec]
    legs.append(areas.index(sec))
    


    for tc in range(len(legs)):
        x, y, w, h = cv2.boundingRect(contours[legs[tc]])
#         print(x, y, w, h)
        dd=cv2.rectangle(img1,(x,y),(x+w,y+h), (0, 255, 0), 2)
        
    plt.figure(figsize=(10,10))
# #     print('number:', match_int[oi])
    plt.subplot(1,2,1)
    plt.imshow(img2, cmap='gray')
    
    plt.subplot(1,2,2)
    plt.imshow(img1, cmap='gray')
